# %% [markdown]
# Naming packages
# ===============
#
# We covered the PEP 8 guidelines for naming packages. In this exercise, you'll use that knowledge to identify a package following the requirements.
#
# For additional reference, you can view the [PEP 8 section on package naming here](https://www.python.org/dev/peps/pep-0008/#package-and-module-name)
#
# ### Instructions
#
# *   The possible package names to `import` are the following: `text_analyzer`, `textAnalyzer`, `TextAnalyzer`, & `__text_analyzer__`.
# *   `import` the package from the list above that follows the PEP 8 naming conventions.

# %%
# Import the package with a name that follows PEP 8
import text_analyzer

# %% [markdown]
# Recognizing packages
# ====================
#
# The structure of your directory tree is printed below. You'll be working in the file `my_script.py` that you can see in the tree.
#
#     recognizing_packages
#     ├── MY_PACKAGE
#     │&nbsp;&nbsp; └── _init_.py
#     ├── package
#     │&nbsp;&nbsp; └── __init__.py
#     ├── package_py
#     │&nbsp;&nbsp; └── __init__
#     │&nbsp;&nbsp;     └── __init__.py
#     ├── py_package
#     │&nbsp;&nbsp; └── __init__.py
#     ├── pyackage
#     │&nbsp;&nbsp; └── init.py
#     └── my_script.py
#
#
# ### Instructions
#
# *   Use the information from the context to identify the packages in the directory that follow the minimal structure.
# *   `import` the two packages that follow the minimal package requirements.
# *   Use `help()` to print information about each imported package.

# %%
# %%script false
#
# # Import local packages
# import package
# import py_package
#
# # View the help for each package
# help(package)
# help(py_package)
# Out:
# Couldn't find program: 'false'

# %% [markdown]
# Adding functionality to your package
# ====================================
#
# Thanks to your work before, you already have a skeleton for your python package. In this exercise, you will work to define the functions needed for a text analysis of word usage.
#
# In the file `counter_utils.py`, you will write 2 functions to be a part of your package: `plot_counter` and `sum_counters`. The structure of your package can be seen in the tree below. For the coding portions of this exercise, you will be working in the file `counter_utils.py`.
#
#     text_analyzer
#     ├── __init__.py
#     └── counter_utils.py
#
#
# ### Instructions 1/3
#
# *   Define `top_items` using `plot_counter`'s inputs.

# %%
# Import needed functionality
from collections import Counter

def plot_counter(counter, n_most_common=5):
  # Subset the n_most_common items from the input counter
  top_items = counter.most_common(n_most_common)
  # Plot `top_items`
  plot_counter_most_common(top_items)

# %% [markdown]
# ### Instructions 2/3
#
# *   Return the correct output from `sum_counters`.

# %%
# Import needed functionality
from collections import Counter

def sum_counters(counters):
  # Sum the inputted counters
  return sum(counters, Counter())

# %% [markdown]
# ### Instructions 3/3
#
# #### Question
#
#
# You just wrote two functions for your package in the file `counter_utils.py` named `plot_counter` & `sum_counters`. Which of the following lines would correctly import these functions in `__init__.py` using relative import syntax?
#
# #### Possible answers
#
# `from counter_utils import plot_counter, sum_counters`
#
# **from .counter_utils import plot_counter, sum_counters**
#
# `from . import plot_counter, sum_counters`
#
# `from .counter_utils import plot_counter & sum_counters`

# %% [markdown]
# Remember to use the dot notation needed for a relative import.

# %% [markdown]
# Using your package's new functionality
# ======================================
#
# You've now created some great functionality for text analysis to your package. In this exercise, you'll leverage your package to analyze some tweets written by DataCamp & DataCamp users.
#
# The object `word_counts` is loaded into your environment. It contains a list of `Counter` objects that contain word counts from a sample of DataCamp tweets.
#
# The structure you've created can be seen in the tree below. You'll be working in `my_script.py`.
#
#     working_dir
#     ├── text_analyzer
#     │    ├── __init__.py
#     │    ├── counter_utils.py
#     └── my_script.py
#
#
# ### Instructions
#
# *   `import` your `text_analyzer` at the top of the script.
# *   Use the `sum_counters()` function from `text_analyzer` to aggregate all the `Counter`s in `word_counts`.
# *   Use the `plot_counter()` function from `text_analyzer` to visualize the tweet's most used words while tweeting.

# %%
# Load variables

from collections import Counter
word_counts = [Counter({'H': 2, 'O': 2, 'DataCamp': 1, 'Introduction': 1, 'to': 1, 'AutoML': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'will': 1, 'learn': 1, 'about': 1, 'and': 1, 'have': 1, 'a': 1, 'glimpse': 1, 'of': 1, 'its': 1, 'auto': 1}), Counter({'DataCamp': 1, 'Stocks': 1, 'Significance': 1, 'Testing': 1, 'p': 1, 'Hacking': 1, 'Learn': 1, 'how': 1, 'to': 1, 'manipulate': 1, 'time': 1, 'series': 1, 'data': 1, 'with': 1, 'pandas': 1, 'and': 1, 'co': 1}), Counter({'RT': 1, '@cbismuth': 1, 'Linear': 1, 'regression': 1, 'example': 1, 'with': 1, 'most': 1, 'significant': 1, 'features': 1, 'detection': 1, '#DataCamp': 1, '#DataScience': 1, '#Python': 1, '#sklearn': 1}), Counter({'Linear': 1, 'regression': 1, 'example': 1, 'with': 1, 'most': 1, 'significant': 1, 'features': 1, 'detection': 1, '#DataCamp': 1, '#DataScience': 1, '#Python': 1, '#sklearn': 1}), Counter({'Basic': 1, 'linear': 1, 'regression': 1, 'example': 1, '#DataCamp': 1, '#DataScience': 1, '#Python': 1, '#sklearn': 1}), Counter({'RT': 1, '@David': 1, 'Makinde': 1, 'I': 1, 'just': 1, 'completed': 1, 'Introduction': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1, '#Datacamp': 1, '#DataScience': 1, '#Python': 1}), Counter({'DataCamp': 2, 'a': 2, 'Enter': 1, 'the': 1, '#DataFramedChallenge': 1, 'for': 1, 'chance': 1, 'to': 1, 'be': 1, 'on': 1, 'an': 1, 'upcoming': 1, 'podcast': 1, 'segment': 1, 'has': 1, 'pod': 1}), Counter({'Python': 2, 'DataCamp': 1, 'Introduction': 1, 'to': 1, 'Metaclasses': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'learn': 1, 'about': 1, 'metaclasses': 1, 'in': 1, 'by': 1, 'De': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'Introduction': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1, '#Datacamp': 1, '#DataScience': 1, '#Python': 1}), Counter({'RT': 1, '@cbismuth': 1, 'My': 1, 'pretty': 1, 'first': 1, 'classifier': 1, '#DataCamp': 1, '#Python': 1, '#sklearn': 1}), Counter({'My': 1, 'pretty': 1, 'first': 1, 'classifier': 1, '#DataCamp': 1, '#Python': 1, '#sklearn': 1}), Counter({'RT': 1, '@ascentt': 1, 'The': 1, 'different': 1, '#DataScience': 1, 'roles': 1, 'on': 1, 'the': 1, 'job': 1, 'market': 1, '#SoftwareTesting': 1, '#DataEngineer': 1, '#DataScientist': 1}), Counter({'The': 1, 'different': 1, '#DataScience': 1, 'roles': 1, 'on': 1, 'the': 1, 'job': 1, 'market': 1, '#SoftwareTesting': 1, '#DataEngineer': 1}), Counter({'de': 4, 'la': 3, 'Consegu': 1, 'el': 1, 'contacto': 1, 'una': 1, 'las': 1, 'encargadas': 1, 'divisi': 1, 'n': 1, 'inform': 1, 'tica': 1, 'OPP': 1, 'gracias': 1, 'a': 1, 'gente': 1, 'del': 1}), Counter({'Weapons': 1, 'of': 1, 'Math': 1, 'Destruction': 1, '#datacamp': 1, '#podcast': 1}), Counter({'DataCamp': 1, 'Shareable': 1, 'Data': 1, 'Science': 1, 'with': 1, 'Kyso': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'learn': 1, 'how': 1, 'to': 1, 'create': 1, 'publishable': 1, 'and': 1, 'reprod': 1}), Counter({'done': 2, 'Studying': 1, 'has': 1, 'to': 1, 'be': 1, 'every': 1, 'day': 1, 'prepare': 1, 'yourself': 1, 'for': 1, 'the': 1, 'next': 1, 'opportunity': 1, 'A': 1, 'leader': 1, 'must': 1, 'show': 1, 'how': 1, 'its': 1}), Counter({'@DataCamp': 1, '#learningR': 1, '#programming': 1, '#datacamp': 1}), Counter({'Trilha': 1, 'incr': 1, 'vel': 1, 'de': 1, 'Programa': 1, 'o': 1, 'em': 1, 'Python': 1, 'do': 1, 'projeto': 1, 'DataCamp': 1, 'conclu': 1, 'da': 1, 'com': 1, 'sucesso': 1, '#DataCamp': 1, '#DataScience': 1}), Counter({'de': 3, 'Depois': 1, 'um': 1, 'longo': 1, 'dia': 1, 'trabalho': 1, 'hora': 1, 'investir': 1, 'no': 1, 'futuro': 1, '#OQueVamosAprenderHoje': 1, '#datascience': 1, '#dsa': 1}), Counter({'RT': 1, '@charlyingsparks': 1, 'This': 1, 'is': 1, 'so': 1, 'spot': 1, 'on': 1, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedchallenge': 1, '@hmason': 1, '#empathy': 1, '#datascience': 1, '#datacamp': 1}), Counter({'Naive': 2, 'Bayes': 2, 'using': 2, 'RT': 1, '@gastronomy': 1, 'DataCamp': 1, 'Classification': 1, 'Scikit': 1, 'learn': 1, 'Learn': 1, 'how': 1, 'to': 1, 'build': 1, 'and': 1, 'evaluate': 1, 'a': 1, 'Classifier': 1}), Counter({'Naive': 2, 'Bayes': 2, 'DataCamp': 1, 'Classification': 1, 'using': 1, 'Scikit': 1, 'learn': 1, 'Learn': 1, 'how': 1, 'to': 1, 'build': 1, 'and': 1, 'evaluate': 1, 'a': 1, 'Classifi': 1}), Counter({'This': 1, 'is': 1, 'so': 1, 'spot': 1, 'on': 1, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedchallenge': 1, '@hmason': 1, '#empathy': 1, '#datascience': 1, '#datacamp': 1}), Counter({'If': 1, 'you': 1, 'want': 1, 'to': 1, 'learn': 1, 'Data': 1, 'Science': 1, 'start': 1, 'with': 1, 'one': 1, 'of': 1, 'these': 1, 'programming': 1, 'classes': 1, 'by': 1, '@venturidb': 1}), Counter({'Learning': 1, 'about': 1, '#Shiny': 1, 'in': 1, '#Datacamp': 1, 'with': 1, '@minebocek': 1}), Counter({'RT': 1, '@aaysbt': 1, 'Day': 1, 'I': 1, 'jsut': 1, 'completed': 1, 'the': 1, 'statistical': 1, 'thingking': 1, 'course': 1, '@DataCamp': 1, 'There': 1, 'was': 1, 'lot': 1, 'of': 1, 'thinks': 1, 'to': 1, 'learn': 1, 'my': 1, 'brain': 1, 'is': 1, 'killing': 1, 'me': 1}), Counter({'@BernieMat': 1, '@epi': 1, 'twit': 1, '@DataCamp': 1, '@RStudioJoe': 1, '@zabormetrics': 1}), Counter({'@malco': 1, 'barrett': 1, '@epi': 1, 'twit': 1, '@DataCamp': 1, '@RStudioJoe': 1, '@zabormetrics': 1, 'This': 1, 'is': 1, 'perfect': 1, 'You': 1, 'may': 1, 'have': 1, 'just': 1, 'saved': 1, 'me': 1, 'months': 1, 'of': 1, 'stress': 1, 'in': 1, 'one': 1, 'tweet': 1}), Counter({'@BernieMat': 1, '@epi': 1, 'twit': 1, '@DataCamp': 1, 'DataCamp': 1, 'has': 1, 'a': 1, 'course': 1, 'on': 1, 'survival': 1, 'analysis': 1}), Counter({'@malco': 1, 'barrett': 1, '@epi': 1, 'twit': 1, '@DataCamp': 1, 'And': 1, 'thanks': 1, 'for': 1, 'the': 1, 'refs': 1, 'extremely': 1, 'helpful': 1}), Counter({'@malco': 1, 'barrett': 1, '@epi': 1, 'twit': 1, '@DataCamp': 1, 'Things': 1, 'such': 1, 'as': 1, 'setting': 1, 'up': 1, 'data': 1, 'for': 1, 'survival': 1, 'analysis': 1, 'I': 1, 'use': 1, 'stset': 1, 'religiously': 1, 'in': 1, 'Stata': 1}), Counter({'I': 1, 'can': 1, 't': 1, 'continue': 1, 'the': 1, 'class': 1, 'Text': 1, 'Mining': 1, 'Bag': 1, 'of': 1, 'Words': 1, '@DataCamp': 1}), Counter({'@BernieMat': 1, '@epi': 1, 'twit': 1, 'In': 1, 'general': 1, 'I': 1, 'recommend': 1, '@DataCamp': 1, 'and': 1, 'R': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'RT': 1, '@khalid': 1, 'amer': 1, 'Day': 1, 'of': 1, 'DaysOfCode': 1, 'I': 1, 'have': 1, 'finished': 1, 'the': 1, 'chapter': 1, 'Customizing': 1, 'plots': 1, 'from': 1, 'Introduction': 1, 'to': 1, 'Data': 1, 'Visualization': 1, 'with': 1, 'P': 1}), Counter({'to': 2, 'RT': 1, '@DataCamp': 1, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'Python': 1, 'Metaclasses': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'learn': 1, 'what': 1, '#metaclasses': 1, 'are': 1, 'how': 1, 'implement': 1, 'them': 1, 'in': 1, '#Py': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1}), Counter({'to': 2, 'Business': 1, 'people': 1, 'do': 1, 'not': 1, 'need': 1, 'apologize': 1, 'for': 1, 'wanting': 1, 'know': 1, 'what': 1, 'the': 1, 'customer': 1, 'wants': 1, '@andrewgelman': 1, 'with': 1}), Counter({'data': 2, 'a': 2, 'sample': 2, 'Big': 1, 'tends': 1, 'to': 1, 'be': 1, 'messy': 1, 'Instead': 1, 'of': 1, 'random': 1, 'you': 1, 'often': 1, 'get': 1, 'convenient': 1, '@andrewgelman': 1}), Counter({'@DataCamp': 1, 'do': 1, 'you': 1, 'have': 1, 'a': 1, 'curriculum': 1, 'suggestion': 1, 'to': 1, 'mimic': 1, 'the': 1, 'Quantitative': 1, 'Analyst': 1, 'with': 1, 'R': 1, 'track': 1, 'but': 1, 'focused': 1, 'on': 1}), Counter({'RT': 1, '@mustafanafees': 1, '@DataCamp': 1, 's': 1, 'Data': 1, 'Science': 1, 'And': 1, '#MachineLearning': 1, 'Programs': 1, 'A': 1, 'Review': 1}), Counter({'@drjekyll': 1, '@DataCamp': 1, '@dataquestio': 1, '@kaggle': 1, 'ooh': 1, 'cool': 1, 'I': 1, 'don': 1, 't': 1, 'know': 1, 'them': 1, 'might': 1, 'give': 1, 'something': 1, 'a': 1, 'try': 1}), Counter({'@iC': 1, 'dE': 1, '@dataquestio': 1, '@DataCamp': 1, 'both': 1, 'offer': 1, 'courses': 1, 'that': 1, 'are': 1, 'really': 1, 'good': 1, 'I': 1, 'm': 1, 'doing': 1, 'the': 1, 'python': 1, 'pipeline': 1, 'and': 1, 'it': 1, 's': 1, 'free': 1}), Counter({'good': 2, '@Dame': 1, 'Of': 1, 'Spades': 1, '@DataCamp': 1, '@dataquestio': 1, 'both': 1, 'offer': 1, 'free': 1, 'courses': 1, 'that': 1, 'are': 1, 'really': 1, '@kaggle': 1, 'is': 1, 'another': 1, 'one': 1, 'wi': 1}), Counter({'for': 2, 'Thanks': 1, '@NickCarchedi': 1, 'and': 1, '@DataCamp': 1, 'Intro': 1, 'to': 1, 'SQL': 1, 'Data': 1, 'Science': 1, 'Great': 1, 'course': 1}), Counter({'RT': 1, '@DataCamp': 1, 'Analyzing': 1, 'Police': 1, 'Activity': 1, 'with': 1, 'pandas': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'practice': 1, 'cleaning': 1, 'messy': 1, 'data': 1, 'create': 1, 'visualizations': 1, 'This': 1, 'cour': 1}), Counter({'Day': 1, 'I': 1, 'jsut': 1, 'completed': 1, 'the': 1, 'statistical': 1, 'thingking': 1, 'course': 1, '@DataCamp': 1, 'There': 1, 'was': 1, 'lot': 1, 'of': 1, 'thinks': 1, 'to': 1, 'learn': 1, 'my': 1, 'brain': 1, 'is': 1}), Counter({'to': 3, 'RT': 1, '@gelliottmorris': 1, 'Want': 1, 'learn': 1, 'how': 1, 'analyze': 1, 'political': 1, 'data': 1, 'Trying': 1, 'figure': 1, 'out': 1, '#rstats': 1, 'and': 1, 'want': 1, 'a': 1, 'familiar': 1, 'dataset': 1, 'I': 1, 've': 1, 'got': 1, 'somethi': 1}), Counter({'RT': 1, '@drjekyll': 1, 'DaysOfCode': 1, 'R': 1, 'D': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'@DataCamp': 1, 's': 1, 'Data': 1, 'Science': 1, 'And': 1, '#MachineLearning': 1, 'Programs': 1, 'A': 1, 'Review': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'can': 2, '@nnstats': 1, '@DataCamp': 1, 'Another': 1, 'question': 1, 'any': 1, 'special': 1, 'reasons': 1, 'for': 1, 'using': 1, 'RStata': 1, 'Are': 1, 'there': 1, 'things': 1, 'Stata': 1, 'do': 1, 'that': 1, 'R': 1, 't': 1, 'Tq': 1}), Counter({'#Python': 1, 'vs': 1, 'R': 1, 'battle': 1, 'for': 1, 'supremacy': 1, 'in': 1, '#DataScience': 1, '#Infographic': 1, 'by': 1, '@DataCamp': 1, '#BigData': 1}), Counter({'we': 3, 'It': 2, 'be': 2, 'awesome': 2, 'if': 2, 'could': 2, '@DataCamp': 1, 'would': 1, 'bookmark': 1, 'courses': 1, 're': 1, 'interested': 1, 'in': 1, 'd': 1, 'even': 1, 'more': 1, 'create': 1, 'playlists': 1}), Counter({'with': 2, 'the': 2, 'to': 2, 'RT': 1, '@DataCamp': 1, 'Modeling': 1, 'Data': 1, 'in': 1, 'Tidyverse': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'will': 1, 'learn': 1, 'model': 1, 'data': 1, 'Models': 1, 'attempt': 1, 'capture': 1, 'relatio': 1}), Counter({'@JamesMarsh': 1, '@DataCamp': 1, 'Thanks': 1}), Counter({'the': 2, '@ShipSystem': 1, '@DataCamp': 1, 'I': 1, 'did': 1, 'think': 1, 'interface': 1, 'worked': 1, 'well': 1, 'and': 1, 'directions': 1, 'were': 1, 'clear': 1, 'most': 1, 'of': 1, 'time': 1}), Counter({'@JamesMarsh': 1, '@DataCamp': 1, 'any': 1, 'feedback': 1}), Counter({'to': 2, 'I': 1, 'm': 1, 'entering': 1, '#dataframedchallenge': 1, 'and': 1, 'you': 1, 'll': 1, 'see': 1, 'me': 1, 'coming': 1, 'Can': 1, 't': 1, 'wait': 1, 'listen': 1, 'some': 1, 'great': 1, 'podcasts': 1, '@DataCamp': 1, '@hugobowne': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Introduction': 1, 'to': 1, 'R': 1}), Counter({'the': 2, 'Thoroughly': 1, 'enjoyed': 1, 'Introduction': 1, 'to': 1, 'Tidyverse': 1, 'course': 1, '@DataCamp': 1, 'by': 1, '@drob': 1, 'Great': 1, 'instructor': 1}), Counter({'to': 2, 'RT': 1, '@jenineharris': 1, 'I': 1, 'am': 1, 'so': 1, 'excited': 1, 'officially': 1, 'be': 1, 'a': 1, '@DataCamp': 1, 'instructor': 1, 'Thank': 1, 'you': 1, 'the': 1, 'fantastic': 1, '@old': 1, 'man': 1, 'chester': 1, 'and': 1, '@venturidb': 1, 'for': 1, 'w': 1}), Counter({'@jenineharris': 1, '@DataCamp': 1, '@old': 1, 'man': 1, 'chester': 1, '@venturidb': 1, 'WHAT': 1, 'Congrats': 1, 'Dr': 1, 'HaRRis': 1}), Counter({'the': 2, 'Thoroughly': 1, 'enjoyed': 1, 'Career': 1, 'Track': 1, 'Data': 1, 'Scientist': 1, 'with': 1, 'R': 1, '@DataCamp': 1, 'course': 1, 'great': 1, 'instructors': 1, 'getting': 1, 'most': 1, 'ou': 1}), Counter({'to': 3, 'Want': 1, 'learn': 1, 'how': 1, 'analyze': 1, 'political': 1, 'data': 1, 'Trying': 1, 'figure': 1, 'out': 1, '#rstats': 1, 'and': 1, 'want': 1, 'a': 1, 'familiar': 1, 'dataset': 1, 'I': 1, 've': 1, 'got': 1, 'som': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Cleaning': 1, 'Data': 1, 'in': 1, 'R': 1, '@DataCamp': 1, 'Learned': 1, 'a': 1, 'lot': 1, 'of': 1, 'functions': 1, 'from': 1, '#tidyr': 1, '#stringr': 1, 'and': 1, '#lubridate': 1, 'packages': 1}), Counter({'Thoroughly': 1, 'enjoyed': 1, 'the': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1, '@DataCamp': 1, 'course': 1, 'by': 1, '@old': 1, 'man': 1, 'chester': 1, 'Great': 1, 'instructor': 1}), Counter({'RT': 1, '@DataCamp': 1, 'Did': 1, 'you': 1, 'already': 1, 'get': 1, 'your': 1, 'Pandas': 1, 'basics': 1, 'cheat': 1, 'sheet': 1}), Counter({'DaysOfCode': 1, 'R': 1, 'D': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'to': 2, '@DataCamp': 1, 'Here': 1, 's': 1, 'another': 1, 'introduction': 1, 'K': 1, 'Means': 1, 'clustering': 1, 'analysis': 1, 'applied': 1, 'UK': 1, 'Police': 1, 'data': 1}), Counter({'@DannyIsSerious': 1, '@nnstats': 1, '@DataCamp': 1, 'How': 1, 'good': 1, 'is': 1, 'the': 1, 'Rstata': 1, 'package': 1}), Counter({'RT': 1, '@simplivllc': 1, 'Python': 1, 'Programming': 1, 'Certification': 1, 'Course': 1, 'OFF': 1, '#technology': 1, '#Software': 1, '#MachineLearning': 1, '#tech': 1, '#educ': 1}), Counter({'the': 2, 'RT': 1, '@nnstats': 1, 'ok': 1, 'responses': 1, 'to': 1, 'data': 1, 'science': 1, 'questions': 1, 'that': 1, 'have': 1, 'been': 1, 'thrown': 1, 'my': 1, 'way': 1, 'in': 1, 'last': 1, 'hours': 1, 'Python': 1, 'or': 1, 'R': 1, 'doesn': 1, 't': 1, 'matter': 1}), Counter({'just': 2, 'many': 2, 'a': 2, 'RT': 1, '@pisastero': 1, 'I': 1, 've': 1, 'discovered': 1, 'ggthemes': 1, 'and': 1, 'the': 1, 'hours': 1, 'of': 1, '@DataCamp': 1, 'have': 1, 'paid': 1, 'off': 1, 'million': 1, 'times': 1, 'This': 1, 'is': 1, 'game': 1, 'change': 1}), Counter({'week': 2, 'Just': 1, 'got': 1, 'back': 1, 'from': 1, 'a': 1, 'in': 1, 'Dublin': 1, 'with': 1, '@DataCamp': 1, 'for': 1, 'our': 1, 'work': 1, 'and': 1, 'I': 1, 'only': 1, 'have': 1, 'or': 1, 'so': 1, 'Github': 1, 'notifications': 1, 'far': 1, 'less': 1, 'than': 1, 'expected': 1}), Counter({'from': 2, 'me': 2, 'RT': 1, '@sctyner': 1, 'Back': 1, 'vacation': 1, 'today': 1, 'and': 1, 'this': 1, 'lovely': 1, 'gift': 1, 'my': 1, 'friend': 1, '@chendaniely': 1, 'was': 1, 'waiting': 1, 'for': 1, 'Which': 1, 'reminds': 1, 'I': 1, 'need': 1, 'to': 1, 'get': 1}), Counter({'from': 2, 'me': 2, 'Back': 1, 'vacation': 1, 'today': 1, 'and': 1, 'this': 1, 'lovely': 1, 'gift': 1, 'my': 1, 'friend': 1, '@chendaniely': 1, 'was': 1, 'waiting': 1, 'for': 1, 'Which': 1, 'reminds': 1, 'I': 1}), Counter({'for': 2, 'to': 2, 'Data': 1, 'science': 1, 'biologists': 1, 'course': 1, '@ucl': 1, 'is': 1, 'underway': 1, 'A': 1, 'massive': 1, 'thank': 1, 'you': 1, '@DataCamp': 1, 'giving': 1, 'us': 1, 'access': 1, 'their': 1, 'wonderful': 1, 'tutorials': 1}), Counter({'RT': 1, '@rstudio': 1, '@DukeSSRI': 1, 'has': 1, 'been': 1, 'developing': 1, 'a': 1, 'free': 1, 'part': 1, '@DataCamp': 1, 'series': 1, 'on': 1, 'Causal': 1, 'Inference': 1, 'with': 1, 'R': 1, 'The': 1, 'first': 1, 'parts': 1, 'are': 1, 'up': 1, 'Intro': 1, 'https': 1}), Counter({'@jenineharris': 1, '@DataCamp': 1, '@old': 1, 'man': 1, 'chester': 1, '@venturidb': 1, 'Awesome': 1, 'Congrats': 1}), Counter({'RT': 1, '@aaysbt': 1, 'Day': 1, 'Hypothesis': 1, 'test': 1, 'examples': 1, 'as': 1, 'apart': 1, 'of': 1, 'the': 1, 'statictical': 1, 'thingking': 1, 'course': 1, '@DataCamp': 1, 'DaysOfCode': 1, '#python': 1, '#Statistics': 1, '#Da': 1}), Counter({'to': 2, 'I': 1, 'am': 1, 'so': 1, 'excited': 1, 'officially': 1, 'be': 1, 'a': 1, '@DataCamp': 1, 'instructor': 1, 'Thank': 1, 'you': 1, 'the': 1, 'fantastic': 1, '@old': 1, 'man': 1, 'chester': 1, 'and': 1, '@venturidb': 1}), Counter({'Python': 1, 'Programming': 1, 'Certification': 1, 'Course': 1, 'OFF': 1, '#technology': 1, '#Software': 1, '#MachineLearning': 1}), Counter({'RT': 1, '@DataCamp': 1, 'Intermediate': 1, 'Spreadsheets': 1, 'for': 1, 'Data': 1, 'Science': 1, 'This': 1, 'course': 1, 'will': 1, 'expand': 1, 'your': 1, 'Google': 1, 'Sheets': 1, 'vocabulary': 1, 'You': 1, 'll': 1, 'dive': 1, 'deep': 1, 'into': 1, 'data': 1}), Counter({'RT': 1, '@DataCamp': 1, 'Pivot': 1, 'Tables': 1, 'with': 1, 'Spreadsheets': 1, 'Learn': 1, 'techniques': 1, 'such': 1, 'as': 1, 'sorting': 1, 'subtotaling': 1, 'filtering': 1, 'your': 1, 'data': 1, 'using': 1, 'real': 1, 'world': 1, 'example': 1}), Counter({'TensorBoard': 2, 'you': 2, 'RT': 1, '@DataCamp': 1, 'Could': 1, 'help': 1, 'This': 1, 'tutorial': 1, 'will': 1, 'guide': 1, 'on': 1, 'how': 1, 'to': 1, 'use': 1, 'which': 1, 'is': 1, 'a': 1, 'fantastic': 1, 'utility': 1, 'that': 1, 'allows': 1}), Counter({'Day': 1, 'Hypothesis': 1, 'test': 1, 'examples': 1, 'as': 1, 'apart': 1, 'of': 1, 'the': 1, 'statictical': 1, 'thingking': 1, 'course': 1, '@DataCamp': 1, 'DaysOfCode': 1, '#python': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Network': 1, 'Science': 1, 'in': 1, 'R': 1, 'A': 1, 'Tidy': 1, 'Approach': 1}), Counter({'@nnstats': 1, '@DataCamp': 1, 'Datacamp': 1, 'was': 1, 'nice': 1, 'bc': 1, 'you': 1, 'never': 1, 'had': 1, 'to': 1, 'set': 1, 'up': 1, 'an': 1, 'environment': 1, 'or': 1, 'manages': 1, 'package': 1, 'version': 1, 'conflicts': 1}), Counter({'RT': 1, '@aaysbt': 1, 'Day': 1, 'bootstrap': 1, 'confidence': 1, 'intervals': 1, 'as': 1, 'a': 1, 'part': 1, 'of': 1, 'the': 1, 'statistical': 1, 'thinking': 1, 'in': 1, '#python': 1, 'course': 1, '@DataCamp': 1, 'DaysOfCode': 1, '#CodeNe': 1}), Counter({'@DataCamp': 1, 'It': 1, 'has': 1, 'been': 1, 'more': 1, 'than': 1, 'days': 1, 'you': 1, 'guys': 1, 'are': 1, 'not': 1, 'resolving': 1, 'the': 1, 'issues': 1, 'I': 1, 'am': 1, 'waiting': 1, 'Request': 1, 'Can': 1, 'a': 1}), Counter({'xts': 2, 'RT': 1, '@DataCamp': 1, 'Are': 1, 'you': 1, 'manipulating': 1, 'time': 1, 'series': 1, 'data': 1, 'in': 1, 'R': 1, 'with': 1, 'Get': 1, 'your': 1, 'copy': 1, 'of': 1, 'DataCamp': 1, 's': 1, 'cheat': 1, 'sheet': 1, 'here': 1}), Counter({'the': 2, 'with': 2, 'RT': 1, '@AndroidCiudadan': 1, 'DaysOfCode': 1, 'R': 1, 'Day': 1, 'I': 1, 've': 1, 'been': 1, 'grinding': 1, '@DataCamp': 1, 'Data': 1, 'science': 1, 'courses': 1, 'python': 1, 'having': 1, 'fun': 1, 'data': 1}), Counter({'the': 2, 'with': 2, 'DaysOfCode': 1, 'R': 1, 'Day': 1, 'I': 1, 've': 1, 'been': 1, 'grinding': 1, '@DataCamp': 1, 'Data': 1, 'science': 1, 'courses': 1, 'python': 1, 'having': 1, 'fun': 1, 'd': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1}), Counter({'RT': 1, '@DataCamp': 1, 'New': 1, 'Tutorial': 1, 'Naive': 1, 'Bayes': 1, 'Classification': 1, 'using': 1, 'Scikit': 1, 'learn': 1, 'Learn': 1, 'how': 1, 'to': 1, 'build': 1, 'and': 1, 'evaluate': 1, 'a': 1, '#Naive': 1, '#Bayes': 1, '#Classifier': 1, 'usin': 1}), Counter({'@nnstats': 1, '@DataCamp': 1, 'Can': 1, 'R': 1, 'run': 1, 'SAP': 1, 'hockey': 1, 'analytics': 1}), Counter({'@MBMiller': 1, 'AT': 1, '@AcademicChatter': 1, '@DataCamp': 1, 'You': 1, 're': 1, 'welcome': 1, 'Hope': 1, 'that': 1, 'helps': 1}), Counter({'@PNgsabrina': 1, '@AcademicChatter': 1, '@DataCamp': 1, 'Great': 1, 'thanks': 1}), Counter({'@MBMiller': 1, 'AT': 1, '@AcademicChatter': 1, 'Highly': 1, 'recommend': 1, '@DataCamp': 1, 'They': 1, 'have': 1, 'detail': 1, 'video': 1, 'tutorials': 1, 'and': 1, 'practices': 1, 'to': 1, 'conso': 1}), Counter({'Good': 1, 'tool': 1, 'for': 1, 'learners': 1, 'of': 1, '#Datascience': 1, '#Data': 1, '#Python': 1, '#Pandas': 1, '#Numpy': 1, '@DataCamp': 1}), Counter({'@nnstats': 1, '@DataCamp': 1, 'Do': 1, 'a': 1, 'Twitter': 1, 'survey': 1, 'for': 1, 'the': 1, 'question': 1, 'Python': 1, 'or': 1, 'R': 1}), Counter({'@nnstats': 1, '@hugobowne': 1, '@DataCamp': 1, 'I': 1, 'like': 1, 'this': 1, 'post': 1}), Counter({'RT': 1, '@DataCamp': 1, 'New': 1, 'Tutorial': 1, 'Shareable': 1, 'Data': 1, 'Science': 1, 'with': 1, '@kyso': 1, 'io': 1, 'Learn': 1, 'how': 1, 'to': 1, 'create': 1, 'publishable': 1, 'and': 1, 'reproducible': 1, 'data': 1, 'science': 1, 'studies': 1, 'on': 1}), Counter({'@PREDStotheCUP': 1, '@nnstats': 1, '@DataCamp': 1, 'Something': 1, 'pirates': 1, 'say': 1}), Counter({'A': 2, '@CodeNewbies': 1, 'Just': 1, 'finished': 1, 'up': 1, 'my': 1, 'semester': 1, 'Looking': 1, 'to': 1, 'keep': 1, 'working': 1, 'on': 1, '@DataCamp': 1, 'courses': 1, 'during': 1, 'the': 1, 'down': 1, 'time': 1}), Counter({'just': 2, 'many': 2, 'a': 2, 'I': 1, 've': 1, 'discovered': 1, 'ggthemes': 1, 'and': 1, 'the': 1, 'hours': 1, 'of': 1, '@DataCamp': 1, 'have': 1, 'paid': 1, 'off': 1, 'million': 1, 'times': 1, 'This': 1, 'is': 1, 'game': 1, 'changer': 1, '#rstats': 1}), Counter({'Day': 1, 'bootstrap': 1, 'confidence': 1, 'intervals': 1, 'as': 1, 'a': 1, 'part': 1, 'of': 1, 'the': 1, 'statistical': 1, 'thinking': 1, 'in': 1, '#python': 1, 'course': 1, '@DataCamp': 1}), Counter({'@Rick': 1, 'Scavetta': 1, 'I': 1, 'recently': 1, 'finished': 1, 'parts': 1, 'and': 1, 'of': 1, 'your': 1, 'Data': 1, 'Visualization': 1, 'with': 1, 'ggplot': 1, 'course': 1, 'on': 1, '@datacamp': 1, 'The': 1, 'd': 1}), Counter({'in': 2, 'how': 2, 'RT': 1, '@DataCamp': 1, 'Tutorial': 1, 'Bivariate': 1, 'Distribution': 1, 'Heatmaps': 1, 'R': 1, 'Learn': 1, 'to': 1, 'visually': 1, 'show': 1, 'the': 1, 'relationship': 1, 'between': 1, 'two': 1, 'features': 1, 'they': 1}), Counter({'@nnstats': 1, '@DataCamp': 1, 'where': 1, 'can': 1, 'i': 1, 'find': 1, 'the': 1, 'numbies': 1}), Counter({'I': 2, 'it': 2, '@nnstats': 1, '@DataCamp': 1, 'So': 1, 'm': 1, 'exploring': 1, 'the': 1, 'RStata': 1, 'package': 1, 'but': 1, 'doesn': 1, 't': 1, 'look': 1, 'like': 1, 'can': 1, 'generate': 1, 'graphical': 1, 'output': 1, 'Am': 1, 'missing': 1, 'something': 1}), Counter({'Hello': 1, '#R': 1, 'DS': 1, 'community': 1, 'I': 1, 'm': 1, 'getting': 1, 'into': 1, 'R': 1, 'course': 1, 'by': 1, '@DataCamp': 1, 'Any': 1, 'tips': 1, 'for': 1, 'some': 1, 'projects': 1, 'to': 1, 'play': 1, 'with': 1}), Counter({'I': 1, 'also': 1, 'vouch': 1, 'for': 1, '@DataCamp': 1}), Counter({'@nnstats': 1, '@DataCamp': 1, 'What': 1, 'is': 1, 'R': 1}), Counter({'the': 2, 'ok': 1, 'responses': 1, 'to': 1, 'data': 1, 'science': 1, 'questions': 1, 'that': 1, 'have': 1, 'been': 1, 'thrown': 1, 'my': 1, 'way': 1, 'in': 1, 'last': 1, 'hours': 1, 'Python': 1, 'or': 1, 'R': 1, 'does': 1}), Counter({'@DataCamp': 1, 'Hi': 1, 'do': 1, 'y': 1, 'all': 1, 'have': 1, 'a': 1, 'phone': 1, 'number': 1, 'for': 1, 'customer': 1, 'service': 1}), Counter({'RT': 1, '@iPablo': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'Pandas': 1, 'foundation': 1, 'course': 1, 'on': 1, '@DataCamp': 1, '#DataScience': 1, '#machinelearning': 1, '#Python': 1, '#learningcurve': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'Pandas': 1, 'foundation': 1, 'course': 1, 'on': 1, '@DataCamp': 1, '#DataScience': 1, '#machinelearning': 1, '#Python': 1, '#learningcurve': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'RT': 1, '@DataCamp': 1, 'This': 1, 'handy': 1, 'one': 1, 'page': 1, 'cheat': 1, 'sheet': 1, 'presents': 1, 'the': 1, '#Python': 1, 'basics': 1, 'that': 1, 'you': 1, 'need': 1, 'to': 1, 'perform': 1, 'data': 1, 'analysis': 1}), Counter({'@DataCamp': 2, 'RT': 1, '@OyewoleIsmail': 1, 'Yes': 1, 'Journey': 1, 'of': 1, 'over': 1, 'days': 1, 'on': 1, 'learning': 1, 'Data': 1, 'Science': 1, 'Thanks': 1, 'and': 1, 'All': 1, 'the': 1, 'instructors': 1, 'for': 1, 't': 1}), Counter({'to': 2, 'RT': 1, '@BCBreeden': 1, 'During': 1, 'my': 1, 'winter': 1, 'break': 1, 'I': 1, 'want': 1, 'stay': 1, 'sharp': 1, 'Going': 1, 'tackle': 1, 'data': 1, 'imports': 1, 'and': 1, 'some': 1, 'visualization': 1, 'courses': 1, 'on': 1, '@DataCamp': 1, '#Data': 1}), Counter({'to': 2, 'During': 1, 'my': 1, 'winter': 1, 'break': 1, 'I': 1, 'want': 1, 'stay': 1, 'sharp': 1, 'Going': 1, 'tackle': 1, 'data': 1, 'imports': 1, 'and': 1, 'some': 1, 'visualization': 1, 'courses': 1, 'on': 1}), Counter({'my': 3, 'day': 3, 'I': 1, 'try': 1, 'to': 1, 'split': 1, 'days': 1, 'when': 1, 'i': 1, 'have': 1, 'time': 1, 'One': 1, 'read': 1, 'books': 1, 'Second': 1, 'continue': 1, 'work': 1, '@DataCamp': 1, 'Third': 1, 'fo': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'pandas': 1, 'Foundations': 1}), Counter({'I': 2, 'to': 2, 'the': 2, 'Though': 1, 'was': 1, 'asked': 1, 'by': 1, '@DataCamp': 1, 'share': 1, 'tweet': 1, 'above': 1, 'am': 1, 'genuinely': 1, 'grateful': 1, 'for': 1, 'opportunity': 1, 'integrate': 1}), Counter({'@AlenaShiryaev': 1, '@DataCamp': 1, 'You': 1, 're': 1, 'welcome': 1, 'Keep': 1, 'an': 1, 'eye': 1, 'out': 1, 'for': 1, 'a': 1, 'great': 1, 'follow': 1, 'up': 1, 'course': 1, 'by': 1, '@mona': 1, 'khm': 1, 'coming': 1, 'soon': 1}), Counter({'a': 1, 'o': 1, 'm': 1, 's': 1, 'de': 1, '@DataCamp': 1, 'esta': 1, 'vez': 1, 'si': 1, 'lo': 1, 'aprovechar': 1, 'jeje': 1, 'hay': 1, 'tanto': 1, 'que': 1, 'aprender': 1}), Counter({'When': 1, 'you': 1, 'start': 1, 'getting': 1, '@DataCamp': 1, 'ads': 1, 'on': 1, 'your': 1, 'kpop': 1, 'videos': 1, '#gradschool': 1, '#gradstudentlife': 1, '#whyme': 1}), Counter({'a': 3, 'the': 2, 'RT': 1, '@DataCamp': 1, 'Watch': 1, 'new': 1, 'webinar': 1, 'by': 1, '@robinson': 1, 'es': 1, 'data': 1, 'scientist': 1, 'at': 1, 'DataCamp': 1, 'who': 1, 'will': 1, 'give': 1, 'brief': 1, 'introduction': 1, 'to': 1, 'concept': 1, 'of': 1}), Counter({'Thoroughly': 1, 'enjoyed': 1, 'the': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1, '@DataCamp': 1, 'course': 1, 'by': 1, '@old': 1, 'man': 1, 'chester': 1, 'Great': 1, 'instructor': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Python': 1, 'Data': 1, 'Science': 1, 'Toolbox': 1, 'Part': 1}), Counter({'in': 2, 'RT': 1, '@muxevola': 1, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedChallenge': 1, '@wesmckinn': 1, 'Pandas': 1, 'built': 1, 'assumption': 1, 'is': 1, 'that': 1, 'data': 1, 'fits': 1, 'memory': 1, 'If': 1, 'you': 1, 'want': 1, 'to': 1}), Counter({'with': 2, 'in': 2, 'the': 2, 'RT': 1, '@DataCamp': 1, 'New': 1, 'Course': 1, 'Working': 1, 'Data': 1, 'Tidyverse': 1, 'You': 1, 'll': 1, 'learn': 1, 'to': 1, 'work': 1, 'data': 1, 'using': 1, 'tools': 1, 'from': 1, '#tidyverse': 1, 'R': 1, 'Througho': 1}), Counter({'RT': 1, '@MercyMarkus': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'a': 2, 'RT': 1, '@RikaGorn': 1, 'Taking': 1, 'notes': 1, 'during': 1, 'podcast': 1, 'is': 1, 'def': 1, 'first': 1, 'for': 1, 'me': 1, 'Just': 1, 'listened': 1, 'to': 1, 'the': 1, 'brilliant': 1, '@AngeBassa': 1, 'on': 1, '@DataCamp': 1, 'DataFramed': 1, 'podcas': 1}), Counter({'to': 2, 'you': 2, '@MercyMarkus': 1, '@DataCamp': 1, 'Congrats': 1, 'Am': 1, 'coming': 1, 'block': 1, 'for': 1, 'teach': 1, 'me': 1, 'oh': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'@DataCamp': 1, 'is': 1, 'generously': 1, 'supporting': 1, 'my': 1, 'class': 1, 'Find': 1, 'out': 1, 'more': 1, 'about': 1, 'DataCamp': 1, 'for': 1, 'the': 1, 'Classroom': 1}), Counter({'Thoroughly': 1, 'enjoyed': 1, 'the': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1, '@DataCamp': 1, 'course': 1, 'by': 1, '@old': 1, 'man': 1, 'chester': 1, 'Great': 1, 'instructor': 1}), Counter({'@DataCamp': 1, 'My': 1, 'annual': 1, 'subscription': 1, 'automatically': 1, 'renewed': 1, 'without': 1, 'any': 1, 'prior': 1, 'warning': 1, 'such': 1, 'as': 1, 'an': 1, 'email': 1, 'I': 1, 'did': 1, 'not': 1, 'want': 1}), Counter({'@DataCamp': 1, 'Any': 1, 'sales': 1, 'coming': 1}), Counter({'my': 3, 'on': 2, 'In': 1, 'addition': 1, 'still': 1, 'work': 1, 'own': 1, 'programming': 1, 'language': 1, 'Work': 1, 'other': 1, 'projects': 1, 'and': 1, 'earn': 1, 'credentials': 1, 'to': 1, 'be': 1, 'a': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Python': 1, 'Data': 1, 'Science': 1, 'Toolbox': 1, 'Part': 1}), Counter({'@DataCamp': 1, '@ProjectJupyter': 1, '@codingphase': 1, 'Mind': 1, 'blown': 1}), Counter({'@DataCamp': 2, '@RikaGorn': 1, '@AngeBassa': 1, '@iRobot': 1, 'This': 1, 'was': 1, 'definitely': 1, 'of': 1, 'my': 1, 'memorable': 1, 'episodes': 1, 'from': 1, 'actually': 1, 'I': 1, 'sho': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intermediate': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'RT': 1, '#Day': 1, '#Python': 1, 'reference': 1, 'material': 1, 'to': 1, 'break': 1, 'up': 1, 'my': 1, '@DataCamp': 1, '@ProjectJupyter': 1, 'routine': 1, 'Also': 1, 'THIS': 1}), Counter({'#Day': 1, '#Python': 1, 'reference': 1, 'material': 1, 'to': 1, 'break': 1, 'up': 1, 'my': 1, '@DataCamp': 1, '@ProjectJupyter': 1, 'routine': 1, 'Also': 1, 'THIS': 1}), Counter({'@RikaGorn': 1, '@AngeBassa': 1, '@DataCamp': 1, '@iRobot': 1}), Counter({'RT': 1, '@Kunkakom': 1, '@maqartan': 1, '@aecoppock': 1, 'Christmas': 1, 'is': 1, 'close': 1, 'On': 1, 'my': 1, 'wishlist': 1, 'A': 1, '@DataCamp': 1, 'intro': 1, 'course': 1, 'to': 1, 'DeclareDesign': 1, 'Thank': 1, 'you': 1, 'Santa': 1}), Counter({'@Kunkakom': 1, '@maqartan': 1, '@DataCamp': 1, 'That': 1, 's': 1, 'a': 1, 'fantastic': 1, 'idea': 1, 'We': 1, 'll': 1, 'send': 1, 'it': 1, 'up': 1, 'north': 1, 'and': 1, 'see': 1, 'what': 1, 'he': 1, 'says': 1}), Counter({'@maqartan': 1, '@aecoppock': 1, 'Christmas': 1, 'is': 1, 'close': 1, 'On': 1, 'my': 1, 'wishlist': 1, 'A': 1, '@DataCamp': 1, 'intro': 1, 'course': 1, 'to': 1, 'DeclareDesign': 1, 'Thank': 1, 'you': 1, 'Santa': 1}), Counter({'@DataCamp': 1, '@jpls': 1, 'Definitely': 1, 'didn': 1, 't': 1, 'get': 1, 'a': 1, 'reminder': 1, 'email': 1}), Counter({'@DataCamp': 1, '@shankarSRC': 1, 'I': 1, 'm': 1, 'in': 1, 'the': 1, 'same': 1, 'situation': 1, 'with': 1, 'no': 1, 'renewal': 1, 'reminder': 1}), Counter({'I': 2, 'have': 2, '@DataCamp': 1, '@jpls': 1, 'the': 1, 'same': 1, 'problem': 1, 'no': 1, 'refund': 1, 'Guess': 1, 'll': 1, 'to': 1, 'dispute': 1, 'it': 1, 'with': 1, 'my': 1, 'CC': 1}), Counter({'a': 2, 'Taking': 1, 'notes': 1, 'during': 1, 'podcast': 1, 'is': 1, 'def': 1, 'first': 1, 'for': 1, 'me': 1, 'Just': 1, 'listened': 1, 'to': 1, 'the': 1, 'brilliant': 1, '@AngeBassa': 1, 'on': 1, '@DataCamp': 1, 'DataFra': 1}), Counter({'to': 2, 'DataCamp': 2, 'RT': 1, '@DataCamp': 1, 'New': 1, 'Project': 1, 'by': 1, '@venturidb': 1, 'Introduction': 1, 'Projects': 1, 'An': 1, 'introduction': 1, 'projects': 1, 'we': 1, 'll': 1, 'walk': 1, 'you': 1, 'through': 1, 'th': 1}), Counter({'Thanks': 1, '@DataCamp': 1, 'for': 1, 'refunding': 1, 'the': 1, 'unintentional': 1, 'annual': 1, 'subscription': 1}), Counter({'for': 2, 'in': 2, 'RT': 1, '@capigian': 1, 'Excited': 1, 'to': 1, 'be': 1, 'using': 1, '@DataCamp': 1, 'the': 1, 'Classroom': 1, 'my': 1, 'Predictive': 1, 'Analytics': 1, 'class': 1, 'They': 1, 'support': 1, 'education': 1, 'free': 1, 'via': 1, 'this': 1}), Counter({'Blended': 1, 'learning': 1, 'zerine': 1, 'g': 1, 'zel': 1, 'bir': 1, 'haber': 1, 'Leuphana': 1, 'niversitesi': 1, 'Data': 1, 'Science': 1, 'k': 1, 'rs': 1, 's': 1, 'premium': 1, 'yelik': 1, 'i': 1, 'in': 1}), Counter({'@DataCamp': 2, 'Yes': 1, 'Journey': 1, 'of': 1, 'over': 1, 'days': 1, 'on': 1, 'learning': 1, 'Data': 1, 'Science': 1, 'Thanks': 1, 'and': 1, 'All': 1, 'the': 1, 'instructors': 1}), Counter({'for': 2, 'Excited': 1, 'to': 1, 'be': 1, 'using': 1, '@DataCamp': 1, 'the': 1, 'Classroom': 1, 'in': 1, 'my': 1, 'Predictive': 1, 'Analytics': 1, 'class': 1, 'They': 1, 'support': 1, 'education': 1, 'free': 1, 'v': 1}), Counter({'RT': 1, '@hahaha': 1, 'it': 1, 'is': 1, 'i': 1, 'Day': 1, 'DaysOfCode': 1, 'Some': 1, '@DataCamp': 1, 'some': 1, '#pytorchudacityscholar': 1, 'challenge': 1, 'Nothing': 1, 'significant': 1, 'in': 1, 'either': 1, 'Just': 1, 'chugg': 1}), Counter({'the': 2, 'Thoroughly': 1, 'enjoyed': 1, 'Introduction': 1, 'to': 1, 'Tidyverse': 1, 'course': 1, '@DataCamp': 1, 'by': 1, '@drob': 1, 'Great': 1, 'instructor': 1}), Counter({'Advice': 1, 'for': 1, 'Applying': 1, 'to': 1, '#DataScience': 1, 'Jobs': 1}), Counter({'@techmariah': 1, '@DataCamp': 1, 'Yes': 1}), Counter({'it': 2, '@hahaha': 1, 'is': 1, 'i': 1, '@DataCamp': 1, 'Keep': 1, 'up': 1, 'Inspired': 1, 'to': 1, 'continue': 1, 'by': 1, 'seeing': 1, 'other': 1, 'women': 1, 'do': 1, 'the': 1, 'challenge': 1, '#WomenWhoCode': 1}), Counter({'Day': 1, 'DaysOfCode': 1, 'Some': 1, '@DataCamp': 1, 'some': 1, '#pytorchudacityscholar': 1, 'challenge': 1, 'Nothing': 1, 'significant': 1, 'in': 1, 'either': 1, 'Just': 1, 'c': 1}), Counter({'I': 3, 'RT': 1, '@AndroidCiudadan': 1, 'DaysOfCode': 1, 'R': 1, 'Day': 1, 'Today': 1, 'started': 1, 'a': 1, 'course': 1, 'of': 1, 'data': 1, 'science': 1, 'on': 1, '@DataCamp': 1, 'learned': 1, 'about': 1, 'numpy': 1, 'matplotlib': 1, 'and': 1}), Counter({'I': 2, 'DaysOfCode': 1, 'R': 1, 'Day': 1, 'Today': 1, 'started': 1, 'a': 1, 'course': 1, 'of': 1, 'data': 1, 'science': 1, 'on': 1, '@DataCamp': 1, 'learned': 1, 'about': 1, 'numpy': 1, 'matplotlib': 1, 'an': 1}), Counter({'you': 2, 'If': 1, 'this': 1, 'football': 1, 'game': 1, 'has': 1, 'down': 1, 'can': 1, 'always': 1, 'learn': 1, 'some': 1, 'linear': 1, 'algebra': 1, 'here': 1, '@DataCamp': 1}), Counter({'Nearly': 2, 'everybody': 2, 'you': 2, 'RT': 1, '@hugobowne': 1, 'If': 1, 'want': 1, 'to': 1, 'run': 1, 'machine': 1, 'learning': 1, 'in': 1, 'production': 1, 'use': 1, 'python': 1, 'Me': 1, 'You': 1, 're': 1, 'wrong': 1, 'WT': 1}), Counter({'RT': 1, '@DaveRubal': 1, 'Bokeh': 1, 'is': 1, 'the': 1, '#Python': 1, '#datavisualization': 1, 'library': 1, 'that': 1, 'enables': 1, 'high': 1, 'performance': 1, 'visual': 1, 'presentation': 1, 'of': 1, 'large': 1, 'datasets': 1, 'in': 1, 'moder': 1}), Counter({'on': 2, 'RT': 1, '@tyleransom': 1, 'I': 1, 'was': 1, 'the': 1, 'team': 1, 'that': 1, 'created': 1, 'these': 1, 'free': 1, '@DataCamp': 1, 'courses': 1, 'causal': 1, 'inference': 1, 'in': 1, 'R': 1, 'Check': 1, 'them': 1, 'out': 1, 'if': 1, 'you': 1, 'think': 1, 'they': 1, 'd': 1, 'be': 1}), Counter({'RT': 1, '@aaysbt': 1, 'Day': 1, 'Statistical': 1, 'thinking': 1, 'for': 1, '#DataScience': 1, 'and': 1, 'learning': 1, 'Parameter': 1, 'estimation': 1, 'by': 1, 'optimization': 1, '@DataCamp': 1, 'DaysOfCode': 1, '#pyth': 1}), Counter({'RT': 1, '@charlyingsparks': 1, 'We': 1, 'can': 1, 't': 1, 'forget': 1, 'to': 1, 'have': 1, 'fun': 1, 'in': 1, 'what': 1, 'we': 1, 'do': 1, '@datacamp': 1, '@hugobowne': 1, 'First': 1, 'and': 1, 'foremost': 1, 'just': 1, 'keep': 1, 'your': 1, 'excitement': 1, 'for': 1, 'it': 1}), Counter({'We': 1, 'can': 1, 't': 1, 'forget': 1, 'to': 1, 'have': 1, 'fun': 1, 'in': 1, 'what': 1, 'we': 1, 'do': 1, '@datacamp': 1, '@hugobowne': 1, 'First': 1, 'and': 1, 'foremost': 1, 'just': 1, 'keep': 1, 'your': 1, 'excitement': 1, 'for': 1}), Counter({'by': 2, 'I': 2, '@DataCamp': 1, '@drob': 1, 'if': 1, 've': 1, 'got': 1, 'good': 1, 'mark': 1, 'at': 1, 'my': 1, 'assessment': 1, 'thanks': 1, 'to': 1, 'your': 1, 'lesson': 1, 'gonna': 1, 'follow': 1, 'them': 1, 'all': 1}), Counter({'New': 1, 'Tutorial': 1, 'posted': 1, 'on': 1, '@DataCamp': 1}), Counter({'RT': 1, '@DataCamp': 1, 'New': 1, 'Tutorial': 1, 'Automated': 1, 'Machine': 1, 'Learning': 1, 'with': 1, 'Auto': 1, 'Keras': 1, 'Learn': 1, 'about': 1, 'automated': 1, 'machine': 1, 'learning': 1, 'and': 1, 'how': 1, 'it': 1, 'can': 1, 'be': 1, 'done': 1, 'using': 1}), Counter({'@dsimposters': 1, '@BecomingDataSci': 1, '@DataCamp': 1, 'Thank': 1, 'you': 1, 'very': 1, 'much': 1, 'I': 1, 'appreciate': 1, 'your': 1, 'input': 1}), Counter({'@jpls': 1, '@DataCamp': 1, 'Same': 1, 'here': 1, 'this': 1, 'is': 1, 'not': 1, 'only': 1, 'shows': 1, 'bad': 1, 'business': 1, 'practices': 1, 'but': 1, 'also': 1, 'the': 1, 'true': 1, 'intentions': 1, 'to': 1, 'rip': 1, 'off': 1}), Counter({'I': 2, '@DataCamp': 1, 'had': 1, 'so': 1, 'much': 1, 'of': 1, 'respect': 1, 'for': 1, 'you': 1, 'guys': 1, 'as': 1, 'your': 1, 'company': 1, 'but': 1, 'today': 1, 'they': 1, 'are': 1, 'all': 1, 'going': 1, 'to': 1, 'be': 1, 'ruined': 1, 'when': 1, 'se': 1}), Counter({'I': 2, 'Hi': 1, '@DataCamp': 1, 'missed': 1, 'the': 1, 'cyber': 1, 'monday': 1, 'sale': 1, 'Any': 1, 'chance': 1, 'can': 1, 'get': 1, 'it': 1, 'still': 1, 'or': 1, 'are': 1, 'there': 1, 'any': 1, 'other': 1, 'sales': 1, 'coming': 1, 'up': 1, 'Thanks': 1}), Counter({'the': 2, 'Thoroughly': 1, 'enjoyed': 1, 'Introduction': 1, 'to': 1, 'Tidyverse': 1, 'course': 1, '@DataCamp': 1, 'by': 1, '@drob': 1, 'Great': 1, 'instructor': 1, 'Welcome': 1}), Counter({'@GalarnykMichael': 1, '@vivekkhetan': 1, 'ism': 1, '@PurpleBooth': 1, '@willems': 1, 'karlijn': 1, '@DataCamp': 1, 'Thanks': 1, 'I': 1, 'think': 1, 'you': 1, 're': 1, 'right': 1, 'and': 1, 'have': 1, 'ju': 1}), Counter({'@markchand': 2, '@PurpleBooth': 1, '@willems': 1, 'karlijn': 1, '@GalarnykMichael': 1, '@DataCamp': 1, 'Great': 1, 'work': 1, 'Keep': 1, 'doing': 1, 'it': 1, 'with': 1}), Counter({'@PurpleBooth': 1, '@vivekkhetan': 1, 'ism': 1, '@willems': 1, 'karlijn': 1, '@GalarnykMichael': 1, '@DataCamp': 1, 'Thanks': 1, 'Good': 1, 'questions': 1, 'I': 1, 'mostly': 1, 'wrote': 1, 'it': 1}), Counter({'@DataCamp': 1, 'MVPs': 1, 'of': 1, 'the': 1, 'team': 1, '@JimSpeckart': 1, 'and': 1, '@mattmasten': 1}), Counter({'on': 2, 'I': 1, 'was': 1, 'the': 1, 'team': 1, 'that': 1, 'created': 1, 'these': 1, 'free': 1, '@DataCamp': 1, 'courses': 1, 'causal': 1, 'inference': 1, 'in': 1, 'R': 1, 'Check': 1, 'them': 1, 'out': 1, 'if': 1, 'you': 1, 'think': 1, 't': 1}), Counter({'@aaysbt': 1, '@DataCamp': 1, 'Kudos': 1}), Counter({'the': 2, 'Thoroughly': 1, 'enjoyed': 1, 'Introduction': 1, 'to': 1, 'Tidyverse': 1, 'course': 1, '@DataCamp': 1, 'by': 1, '@drob': 1, 'Great': 1, 'instructor': 1, 'I': 1, 'am': 1, 'left': 1, 'wonderi': 1}), Counter({'@MercyMarkus': 1, '@DataCamp': 1, 'ok': 1, 'I': 1, 'll': 1, 'go': 1, 'check': 1, 'it': 1, 'out': 1, 'Thank': 1, 'you': 1}), Counter({'the': 3, 'to': 2, '@itsDonmonc': 1, '@DataCamp': 1, 'Just': 1, 'first': 1, 'module': 1, 'you': 1, 'll': 1, 'need': 1, 'pay': 1, 'access': 1, 'rest': 1, 'of': 1, 'course': 1, 'content': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'@MercyMarkus': 1, '@DataCamp': 1, 'is': 1, 'this': 1, 'under': 1, 'one': 1, 'of': 1, 'their': 1, 'free': 1, 'courses': 1}), Counter({'Bokeh': 1, 'is': 1, 'the': 1, '#Python': 1, '#datavisualization': 1, 'library': 1, 'that': 1, 'enables': 1, 'high': 1, 'performance': 1, 'visual': 1, 'presentation': 1, 'of': 1, 'large': 1, 'datasets': 1}), Counter({'@DataCamp': 1, 'Extremely': 1, 'angry': 1, 'to': 1, 'see': 1, 'that': 1, 'my': 1, 'yearly': 1, 'subscription': 1, 'auto': 1, 'renewed': 1, 'without': 1, 'warning': 1, 'today': 1, 'Help': 1, 'article': 1}), Counter({'Day': 1, 'Statistical': 1, 'thinking': 1, 'for': 1, '#DataScience': 1, 'and': 1, 'learning': 1, 'Parameter': 1, 'estimation': 1, 'by': 1, 'optimization': 1, '@DataCamp': 1}), Counter({'text': 2, 'Loved': 1, '@juliasilge': 1, 'tidy': 1, 'mining': 1, 'with': 1, 'R': 1, 'on': 1, '@DataCamp': 1, 'particularly': 1, 'the': 1, 'Shakespeare': 1, 'outfit': 1, '#moreplease': 1}), Counter({'I': 2, 'again': 2, '@DataCamp': 1, 'You': 1, 'have': 1, 'a': 1, 'good': 1, 'product': 1, 'll': 1, 'subscribe': 1, 'to': 1, 'you': 1, 'anytime': 1, 'consider': 1, 'studying': 1, 'Data': 1, 'Science': 1, 'But': 1}), Counter({'@markchand': 1, '@vivekkhetan': 1, 'ism': 1, '@willems': 1, 'karlijn': 1, '@GalarnykMichael': 1, '@DataCamp': 1, 'Great': 1, 'work': 1, 'You': 1, 'have': 1, 'a': 1, 'very': 1, 'approachable': 1, 'wr': 1}), Counter({'Learned': 1, 'a': 1, 'lot': 1, 'with': 1, 'subquerying': 1, 'exercises': 1, 'Thoroughly': 1, 'enjoyed': 1, 'the': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1, '@DataCamp': 1, 'course': 1, 'by': 1}), Counter({'Thoroughly': 1, 'enjoyed': 1, 'the': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1, '@DataCamp': 1, 'course': 1, 'by': 1, '@old': 1, 'man': 1, 'chester': 1, 'Great': 1, 'instructor': 1}), Counter({'More': 3, 'RT': 1, '#Day': 1, 'Methods': 1, 'review': 1, 'in': 1, '@DataCamp': 1, 'Less': 1, 'actual': 1, 'programming': 1, 'today': 1, 'and': 1, 'more': 1, 'focus': 1, 'on': 1, 'those': 1, 'basic': 1, '#Python': 1, 'p': 1}), Counter({'More': 3, '#Day': 1, 'Methods': 1, 'review': 1, 'in': 1, '@DataCamp': 1, 'Less': 1, 'actual': 1, 'programming': 1, 'today': 1, 'and': 1, 'more': 1, 'focus': 1, 'on': 1, 'those': 1, 'bas': 1}), Counter({'and': 2, 'RT': 1, '@DataCamp': 1, 'Working': 1, 'with': 1, 'Dates': 1, 'Times': 1, 'in': 1, 'R': 1, 'by': 1, '@CVWickham': 1, 'This': 1, 'course': 1, 'teaches': 1, 'you': 1, 'the': 1, 'essentials': 1, 'of': 1, 'parsing': 1, 'manipulating': 1, 'computi': 1}), Counter({'s': 2, 'RT': 1, '@nebelgrau': 1, 'Incorporating': 1, '@DataCamp': 1, 'DataFramed': 1, 'into': 1, 'my': 1, 'daily': 1, 'soundstream': 1, 'was': 1, 'a': 1, 'great': 1, 'idea': 1, 'There': 1, 'so': 1, 'much': 1, 'to': 1, 'learn': 1, 'this': 1, 'time': 1, 'fro': 1}), Counter({'I': 2, 'think': 2, 'RT': 1, '@charlyingsparks': 1, '@DataCamp': 1, '@hugobowne': 1, 'we': 1, 'all': 1, 'really': 1, 'need': 1, 'to': 1, 'push': 1, 'for': 1, 'openness': 1, 'of': 1, 'data': 1, 'there': 1, 's': 1, 'an': 1, 'incredible': 1, 'opportun': 1}), Counter({'@markchand': 1, '@vivekkhetan': 1, 'ism': 1, '@PurpleBooth': 1, '@willems': 1, 'karlijn': 1, '@DataCamp': 1, 'Its': 1, 'nice': 1, 'My': 1, 'only': 1, 'advice': 1, 'is': 1, 'to': 1, 'put': 1, 'it': 1, 'a': 1, 'blog': 1, 'ty': 1}), Counter({'I': 2, 'm': 1, 'trying': 1, 'to': 1, 'learn': 1, '#Python': 1, 'so': 1, 'wrote': 1, 'a': 1, 'thing': 1, 'What': 1, 'do': 1, 'you': 1, 'think': 1, 'Internet': 1, 'With': 1, 'thanks': 1, 't': 1}), Counter({'RT': 1, '@mkuehn': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Foundations': 1, 'of': 1, 'Functional': 1, 'Programming': 1, 'with': 1, 'purrr': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Foundations': 1, 'of': 1, 'Functional': 1, 'Programming': 1, 'with': 1, 'purrr': 1}), Counter({'I': 2, 'think': 2, '@DataCamp': 1, '@hugobowne': 1, 'we': 1, 'all': 1, 'really': 1, 'need': 1, 'to': 1, 'push': 1, 'for': 1, 'openness': 1, 'of': 1, 'data': 1, 'there': 1, 's': 1, 'an': 1, 'incredible': 1, 'oppor': 1}), Counter({'@LukeNdatigh': 1, '@DataCamp': 1, 'Thank': 1, 'you': 1}), Counter({'s': 2, 'Incorporating': 1, '@DataCamp': 1, 'DataFramed': 1, 'into': 1, 'my': 1, 'daily': 1, 'soundstream': 1, 'was': 1, 'a': 1, 'great': 1, 'idea': 1, 'There': 1, 'so': 1, 'much': 1, 'to': 1, 'learn': 1, 'this': 1, 't': 1}), Counter({'@MercyMarkus': 1, '@DataCamp': 1, 'Congratulations': 1}), Counter({'to': 2, '@DataCamp': 1, 'Hello': 1, 'I': 1, 'would': 1, 'like': 1, 'speak': 1, 'customer': 1, 'service': 1}), Counter({'@DataCamp': 1, 'Thank': 1, 'you': 1, 'dropped': 1, 'an': 1, 'email': 1}), Counter({'@DataCamp': 1, '#learningR': 1, '#programming': 1, '#datacamp': 1}), Counter({'@DataCamp': 1, '@hugobowne': 1, '@mathbabedotorg': 1, 'I': 1, 'would': 1, 'suggest': 1, 'everyone': 1, 'to': 1, 'first': 1, 'check': 1, 'your': 1, 'support': 1, 'page': 1, 'for': 1, 'number': 1, 'of': 1, 'people': 1}), Counter({'@MercyMarkus': 1, '@DataCamp': 1, 'Sist': 1}), Counter({'is': 2, '@DataCamp': 1, '@hugobowne': 1, '@mathbabedotorg': 1, 'I': 1, 'did': 1, 'there': 1, 'no': 1, 'response': 1, 'This': 1, 'an': 1, 'unethical': 1, 'business': 1, 'conduct': 1, 'Every': 1, 'othe': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'RT': 1, '@DataCamp': 1, 'Scikit': 1, 'learn': 1, 'cheat': 1, 'sheet': 1, '#machinelearning': 1, 'with': 1, '#Python': 1}), Counter({'@DataCamp': 1, '@hugobowne': 1, '@mathbabedotorg': 1, 'Please': 1, 'do': 1, 'not': 1, 'subscribe': 1, 'to': 1, 'this': 1, 'fraud': 1, 'courses': 1, 'Datacamp': 1, 'deducted': 1, 'money': 1, 'from': 1, 'my': 1}), Counter({'@DukeSSRI': 1, 'has': 1, 'been': 1, 'developing': 1, 'a': 1, 'free': 1, 'part': 1, '@DataCamp': 1, 'series': 1, 'on': 1, 'Causal': 1, 'Inference': 1, 'with': 1, 'R': 1, 'The': 1, 'first': 1, 'parts': 1, 'are': 1, 'up': 1}), Counter({'@DataCamp': 1, 'can': 1, 'you': 1, 'please': 1, 'cancel': 1, 'the': 1, 'subscription': 1, 'which': 1, 'got': 1, 'auto': 1, 'processed': 1, 'today': 1}), Counter({'#Day': 1, 'More': 1, 'on': 1, 'the': 1, 'go': 1, 'coding': 1, 'with': 1, 'both': 1, '@DataCamp': 1, '@dcodermobile': 1, 'using': 1, '#Python': 1, 'functions': 1, 'while': 1, 'index': 1, 'calling': 1, 'from': 1, 'a': 1}), Counter({'@DataCamp': 1, 'You': 1, 'guys': 1, 'keep': 1, 'me': 1, 'hooked': 1, 'more': 1, 'than': 1, 'Netflix': 1}), Counter({'t': 2, 'about': 2, 'RT': 1, '@dataiku': 1, 'Being': 1, 'a': 1, 'data': 1, 'science': 1, 'manager': 1, 'isn': 1, 'giving': 1, 'your': 1, 'team': 1, 'all': 1, 'the': 1, 'answers': 1, 'it': 1, 's': 1, 'guiding': 1, 'them': 1, 'there': 1, 'instead': 1, 'Learn': 1, 'how': 1}), Counter({'@nicholdav': 1, '@DarknetDiaries': 1, '@USTpodcast': 1, '@pgmid': 1, '@twimlai': 1, '@DataCamp': 1, '@TalkPython': 1, '@thedollop': 1, '@CucubanoPod': 1, 'Weird': 1, 'flex': 1, 'but': 1, 'OK': 1}), Counter({'@KirkDBorne': 1, '@MusicComposer': 1, '@alcgroup': 1, '@data': 1, 'nerd': 1, '@Shirastweet': 1, '@dez': 1, 'blanchfield': 1, '@digitalcloudgal': 1, '@TeachTheMachine': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Introduction': 1, 'to': 1, 'Data': 1, 'Visualization': 1, 'with': 1, 'Python': 1}), Counter({'RT': 1, '@KirkDBorne': 1, '@NexWebSites': 1, '@MusicComposer': 1, '@alcgroup': 1, '@data': 1, 'nerd': 1, '@Shirastweet': 1, '@dez': 1, 'blanchfield': 1, '@digitalcloudgal': 1, '@TeachTheMachine': 1, '@edXOnlin': 1}), Counter({'@NexWebSites': 1, '@MusicComposer': 1, '@alcgroup': 1, '@data': 1, 'nerd': 1, '@Shirastweet': 1, '@dez': 1, 'blanchfield': 1, '@digitalcloudgal': 1, '@TeachTheMachine': 1}), Counter({'RT': 1, '@ikayz': 1, 'Done': 1, 'up': 1, 'and': 1, 'running': 1, 'with': 1, 'Python': 1, 'for': 1, '#DataScience': 1, '#DevCTraining': 1, 'cheers': 1, '@DataCamp': 1}), Counter({'Done': 1, 'up': 1, 'and': 1, 'running': 1, 'with': 1, 'Python': 1, 'for': 1, '#DataScience': 1, '#DevCTraining': 1, 'cheers': 1, '@DataCamp': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'in': 2, '@MihiretuKebede': 1, '@thomasp': 1, '@DataCamp': 1, 'Yes': 1, 'I': 1, 'though': 1, 'there': 1, 'was': 1, 'a': 1, 'section': 1, 'the': 1, 'current': 1, 'courses': 1, 'This': 1, 'will': 1, 'appear': 1}), Counter({'RT': 1, '@charlyingsparks': 1, 'This': 1, 'is': 1, 'so': 1, 'spot': 1, 'on': 1, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedchallenge': 1, '@hmason': 1, '#empathy': 1, '#datascience': 1, '#datacamp': 1}), Counter({'to': 3, 'Thanks': 1, '@DataCamp': 1, 'for': 1, 'making': 1, 'my': 1, 'Bioinformatics': 1, 'class': 1, 'better': 1, 'next': 1, 'year': 1, 'Excited': 1, 'use': 1, 'your': 1, 'lessons': 1, 'get': 1, 'biologists': 1, 'love': 1, 'R': 1}), Counter({'@DerekChia': 1, '@DataCamp': 1, 'Thanks': 1, 'Be': 1, 'on': 1, 'the': 1, 'lookout': 1, 'for': 1, 'a': 1, 'great': 1, 'follow': 1, 'up': 1, 'course': 1, 'from': 1, '@mona': 1, 'khm': 1, 'coming': 1, 'soon': 1}), Counter({'RT': 1, '@uomodlamansarda': 1, '@hugobowne': 1, '@DataCamp': 1, '@mathbabedotorg': 1, 'Your': 1, 'podcasts': 1, 'are': 1, 'amazing': 1, 'I': 1, 'never': 1, 'miss': 1, 'one': 1}), Counter({'RT': 1, '@aaysbt': 1, 'Day': 1, 'I': 1, 'have': 1, 'been': 1, 'complete': 1, 'the': 1, 'course': 1, 'Statistical': 1, 'Thinking': 1, 'in': 1, 'Python': 1, 'Part': 1, '@DataCamp': 1, 'DaysOfCode': 1, '#PYTHONPROGRAMMING': 1, '#P': 1}), Counter({'@hahaha': 1, 'it': 1, 'is': 1, 'i': 1, '@DataCamp': 1, 'I': 1, 'just': 1, 'finished': 1, 'lesson': 1, 'as': 1, 'well': 1}), Counter({'@nerdnomadmom': 1, '@DollaSignBeezy': 1, '@DataCamp': 1, 'Look': 1, 'at': 1, 'the': 1, 'Azure': 1, 'certs': 1}), Counter({'This': 1, 'is': 1, 'so': 1, 'spot': 1, 'on': 1, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedchallenge': 1, '@hmason': 1, '#empathy': 1, '#datascience': 1, '#datacamp': 1}), Counter({'Day': 1, 'I': 1, 'have': 1, 'been': 1, 'complete': 1, 'the': 1, 'course': 1, 'Statistical': 1, 'Thinking': 1, 'in': 1, 'Python': 1, 'Part': 1, '@DataCamp': 1, 'DaysOfCode': 1}), Counter({'it': 2, '@muxevola': 1, '@DataCamp': 1, '@hugobowne': 1, '@wesmckinn': 1, 'although': 1, 'even': 1, 'if': 1, 'should': 1, 'fit': 1, 'in': 1, 'memory': 1, 'sometimes': 1, 'doesn': 1, 't': 1}), Counter({'the': 2, 'RT': 1, '@muxevola': 1, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedChallenge': 1, '@wesmckinn': 1, 'Pandas': 1, 'is': 1, 'occupying': 1, 'sweet': 1, 'spot': 1, 'of': 1, 'being': 1, 'ultimate': 1, 'Swiss': 1, 'army': 1, 'knif': 1}), Counter({'RT': 1, '@muxevola': 1, '@DataCamp': 1, '@hugobowne': 1, '@mathbabedotorg': 1, '#DataFramedChallenge': 1, 'Fairness': 1, 'and': 1, 'transparency': 1, 'do': 1, 'not': 1, 'seem': 1, 'a': 1, 'proper': 1, 'incentive': 1, 'to': 1, 'undergo': 1}), Counter({'Thoroughly': 1, 'enjoyed': 1, 'the': 1, 'Joining': 1, 'Data': 1, 'in': 1, 'PostgreSQL': 1, '@DataCamp': 1, 'course': 1, 'by': 1, '@old': 1, 'man': 1, 'chester': 1, 'Great': 1, 'instructor': 1}), Counter({'@nerdnomadmom': 1, '@DollaSignBeezy': 1, '@DataCamp': 1, 'Crazy': 1, 'random': 1, 'but': 1, 'Ari': 1, 'and': 1, 'I': 1, 'have': 1, 'the': 1, 'same': 1, 'birthday': 1, 'lmaoo': 1, 'small': 1, 'world': 1}), Counter({'@nerdnomadmom': 1, '@DollaSignBeezy': 1, '@DataCamp': 1, 'Any': 1, 'hints': 1, 'on': 1, 'how': 1, 'to': 1, 'learn': 1, 'data': 1, 'science': 1}), Counter({'for': 2, '@nerdnomadmom': 1, '@DollaSignBeezy': 1, '@DataCamp': 1, 'Which': 1, 'cert': 1, 'is': 1, 'data': 1, 'science': 1, 'security': 1}), Counter({'@nerdnomadmom': 1, '@DataCamp': 1, 'That': 1, 'Data': 1, 'Science': 1, 'one': 1, 'seems': 1, 'interesting': 1, 'Big': 1}), Counter({'@iPablo': 1, '@DataCamp': 1, 'Congrats': 1, 'keep': 1, 'on': 1, 'going': 1}), Counter({'Having': 1, 'auto': 1, 'renewal': 1, 'of': 1, 'subscription': 1, 'turned': 1, 'on': 1, 'as': 1, 'default': 1, 'is': 1, 'very': 1, 'bad': 1, 'UX': 1, 'Disappointed': 1, '@DataCamp': 1, 'It': 1, 'would': 1, 've': 1, 'been': 1}), Counter({'Just': 1, 'finished': 1, 'my': 1, '@DataCamp': 1, 's': 1, 'Python': 1, 'Programmer': 1, 'Track': 1, 'while': 1, 'have': 1, 'no': 1, 'related': 1, 'background': 1, 'whatsoever': 1, 'with': 1, 'the': 1, 'cour': 1}), Counter({'looking': 2, 'RT': 1, '@jsjoeio': 1, 'Friends': 1, 'who': 1, 'are': 1, 'for': 1, 'a': 1, 'job': 1, 'If': 1, 'you': 1, 're': 1, 'passionate': 1, 'about': 1, 'education': 1, 'JavaScript': 1, 'and': 1, 'to': 1, 'work': 1, 'in': 1, 'NYC': 1, 'check': 1, 'out': 1, 't': 1}), Counter({'@DataCamp': 1, '@hugobowne': 1, '@mathbabedotorg': 1, '#DataFramedChallenge': 1, 'Fairness': 1, 'and': 1, 'transparency': 1, 'do': 1, 'not': 1, 'seem': 1, 'a': 1, 'proper': 1, 'incentive': 1}), Counter({'the': 2, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedChallenge': 1, '@wesmckinn': 1, 'Pandas': 1, 'is': 1, 'occupying': 1, 'sweet': 1, 'spot': 1, 'of': 1, 'being': 1, 'ultimate': 1, 'Swiss': 1}), Counter({'in': 2, '@DataCamp': 1, '@hugobowne': 1, '#DataFramedChallenge': 1, '@wesmckinn': 1, 'Pandas': 1, 'built': 1, 'assumption': 1, 'is': 1, 'that': 1, 'data': 1, 'fits': 1, 'memory': 1, 'If': 1, 'yo': 1}), Counter({'@DataCamp': 1, 'is': 1, 'there': 1, 'a': 1, 'Cyber': 1, 'Monday': 1, 'discount': 1, 'code': 1, 'for': 1, 'this': 1, 'year': 1}), Counter({'RT': 1, '@QuantStratTradR': 1, 'New': 1, 'post': 1, 'using': 1, 'technology': 1, 'from': 1, '@OptimizeRisk': 1, 's': 1, '@DataCamp': 1, 'course': 1}), Counter({'the': 3, '#Day': 1, 'Trying': 1, 'out': 1, '@DataCamp': 1, 'app': 1, 'on': 1, 'go': 1, 'today': 1, 'to': 1, 'further': 1, '#Python': 1, 'benefits': 1, 'gained': 1, 'through': 1, 'repetition': 1}), Counter({'is': 2, 'RT': 1, '@charlyingsparks': 1, '@hugobowne': 1, '@DataCamp': 1, 'inspiration': 1, 'cheap': 1, 'but': 1, 'rigor': 1, 'expensive': 1, '@quaesita': 1, '#truth': 1, '#DataScience': 1, '#dataframedchal': 1}), Counter({'is': 2, '@hugobowne': 1, '@DataCamp': 1, 'inspiration': 1, 'cheap': 1, 'but': 1, 'rigor': 1, 'expensive': 1, '@quaesita': 1, '#truth': 1, '#DataScience': 1, '#dataframedchallenge': 1}), Counter({'RT': 1, '@hahaha': 1, 'it': 1, 'is': 1, 'i': 1, 'Day': 1, 'DaysOfCode': 1, 'Another': 1, 'chapter': 1, '@DataCamp': 1, 'Finished': 1, 'lesson': 1, 'in': 1, 'the': 1, 'pytorch': 1, 'challenge': 1, 'Feels': 1, 'good': 1, 'to': 1, 'be': 1, 'moving': 1}), Counter({'I': 2, 'been': 2, 'RT': 1, '@JamesMarsh': 1, 've': 1, 'using': 1, '@DataCamp': 1, 'free': 1, 'courses': 1, 'in': 1, 'R': 1, 'and': 1, 'must': 1, 'say': 1, 'for': 1, 'a': 1, 'super': 1, 'beginner': 1, 'like': 1, 'me': 1, 'they': 1, 'have': 1, 'pretty': 1, 'intuitive': 1}), Counter({'I': 2, 'been': 2, 've': 1, 'using': 1, '@DataCamp': 1, 'free': 1, 'courses': 1, 'in': 1, 'R': 1, 'and': 1, 'must': 1, 'say': 1, 'for': 1, 'a': 1, 'super': 1, 'beginner': 1, 'like': 1, 'me': 1, 'they': 1, 'have': 1, 'pretty': 1, 'intuitive': 1}), Counter({'looking': 2, 'Friends': 1, 'who': 1, 'are': 1, 'for': 1, 'a': 1, 'job': 1, 'If': 1, 'you': 1, 're': 1, 'passionate': 1, 'about': 1, 'education': 1, 'JavaScript': 1, 'and': 1, 'to': 1, 'work': 1, 'in': 1, 'NYC': 1}), Counter({'Day': 1, 'DaysOfCode': 1, 'Another': 1, 'chapter': 1, '@DataCamp': 1, 'Finished': 1, 'lesson': 1, 'in': 1, 'the': 1, 'pytorch': 1, 'challenge': 1, 'Feels': 1, 'good': 1, 'to': 1, 'be': 1, 'mov': 1}), Counter({'New': 1, 'post': 1, 'using': 1, 'technology': 1, 'from': 1, '@OptimizeRisk': 1, 's': 1, '@DataCamp': 1, 'course': 1}), Counter({'RT': 1, '@DataCamp': 1, 'New': 1, '#DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@pjbull': 1, 'a': 1, 'data': 1, 'scientist': 1, 'for': 1, 'social': 1, 'good': 1, 'and': 1, 'co': 1, 'founder': 1, 'of': 1, '@drivendataorg': 1}), Counter({'@iPablo': 1, '@DataCamp': 1, 'Congratulations': 1}), Counter({'RT': 1, '@DataCamp': 1, 'This': 1, '#SciPy': 1, 'SciPy': 1, 'cheat': 1, 'sheet': 1, 'covers': 1, 'the': 1, 'basics': 1, 'of': 1, 'linear': 1, 'algebra': 1, 'in': 1, '#Python': 1, 'that': 1, 'you': 1, 'need': 1, 'to': 1, 'get': 1, 'started': 1}), Counter({'@DarknetDiaries': 1, 'wonder': 1, 'how': 1, 'easy': 1, 'it': 1, 'would': 1, 'be': 1, 'to': 1, 'scrape': 1, 'the': 1, 'iTunes': 1, 'charts': 1, 'and': 1, 'do': 1, 'some': 1, 'anomaly': 1, 'detection': 1, 'Obvs': 1, 'Apple': 1, 'a': 1}), Counter({'I': 3, 'to': 2, '@CMastication': 1, '@woody': 1, 'gsd': 1, '@voidspace': 1, 'agree': 1, 'started': 1, 'out': 1, 'with': 1, 'just': 1, 'google': 1, 'and': 1, 'was': 1, 'able': 1, 'learn': 1, 'ways': 1, 'do': 1, 'th': 1}), Counter({'a': 2, '@EconoTodd': 1, '@DataCamp': 1, '@hugobowne': 1, 'you': 1, 've': 1, 'got': 1, 'fan': 1, 'Let': 1, 's': 1, 'all': 1, 'get': 1, 'beer': 1, 'soon': 1}), Counter({'el': 2, 'aprendizaje': 2, 'Diferencias': 1, 'entre': 1, 'autom': 1, 'tico': 1, 'y': 1, 'profundo': 1, 'Una': 1, 'visi': 1, 'n': 1, 'general': 1, 'de': 1, 'la': 1, 'Inteligencia': 1, 'Artif': 1}), Counter({'a': 2, 'RT': 1, '@muxevola': 1, 'Fairness': 1, 'is': 1, 'statistical': 1, 'concept': 1, 'It': 1, 's': 1, 'notion': 1, 'that': 1, 'we': 1, 'need': 1, 'to': 1, 'understand': 1, 'at': 1, 'an': 1, 'aggregate': 1, 'level': 1, '@DataCamp': 1, '@hugobowne': 1, '@math': 1}), Counter({'RT': 1, '@spenafajuri': 1, 'Hoy': 1, 'estoy': 1, 'haciendo': 1, 'este': 1, 'curso': 1, 'en': 1, '@DataCamp': 1, 'Designing': 1, 'and': 1, 'Analysing': 1, 'Clinical': 1, 'Trials': 1, 'in': 1, 'R': 1}), Counter({'Hoy': 1, 'estoy': 1, 'haciendo': 1, 'este': 1, 'curso': 1, 'en': 1, '@DataCamp': 1, 'Designing': 1, 'and': 1, 'Analysing': 1, 'Clinical': 1, 'Trials': 1, 'in': 1, 'R': 1}), Counter({'a': 2, 'Fairness': 1, 'is': 1, 'statistical': 1, 'concept': 1, 'It': 1, 's': 1, 'notion': 1, 'that': 1, 'we': 1, 'need': 1, 'to': 1, 'understand': 1, 'at': 1, 'an': 1, 'aggregate': 1, 'level': 1, '@DataCamp': 1}), Counter({'the': 2, 'on': 2, 'RT': 1, '@iPablo': 1, 'I': 1, 'completed': 1, 'Cleaning': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Course': 1, '@DataCamp': 1, 'st': 1, 'of': 1, 'December': 1, 'On': 1, 'to': 1, 'Pandas': 1, 'foundation': 1, '#datascien': 1}), Counter({'RT': 1, '@JSnunki': 1, 'Muy': 1, 'orgullosa': 1, 'Thanks': 1, '@DataCamp': 1, 'ahora': 1, 'somos': 1, 'tal': 1, 'vez': 1}), Counter({'@vannyozogu': 1, '@DataCamp': 1, 'Thank': 1, 'you': 1}), Counter({'@iPablo': 1, '@DataCamp': 1, 'Well': 1, 'done': 1}), Counter({'@DataCamp': 1, 'very': 1, 'useful': 1}), Counter({'the': 2, 'on': 2, 'I': 1, 'completed': 1, 'Cleaning': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Course': 1, '@DataCamp': 1, 'st': 1, 'of': 1, 'December': 1, 'On': 1, 'to': 1, 'Pandas': 1, 'foundation': 1}), Counter({'#AI': 1, '#ArtificialIntelligence': 1, '#ML': 1, '#MachineIntelligence': 1, '#MachineLearning': 1, '#neuralnetwork': 1, '#programmers': 1, '#developers': 1}), Counter({'R': 2, 'RT': 1, '@malco': 1, 'barrett': 1, '@nskajaa': 1, 'For': 1, 'learning': 1, 'in': 1, 'general': 1, 'I': 1, 'always': 1, 'recommend': 1, '@DataCamp': 1, 'and': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'I': 2, 'must': 1, 'say': 1, 'that': 1, 'm': 1, 'very': 1, 'much': 1, 'enjoying': 1, 'the': 1, '@DataCamp': 1, 'Data': 1, 'Framed': 1, 'podcast': 1, 'A': 1, 'nice': 1, 'mix': 1, 'of': 1, 'commentary': 1, 'history': 1, 'and': 1}), Counter({'I': 2, 'a': 2, 'and': 2, 'was': 1, 'selected': 1, 'as': 1, 'recipient': 1, 'of': 1, '@DataCamp': 1, 's': 1, 'Women': 1, 'Minorities': 1, 'scholarship': 1, 'though': 1, 've': 1, 'already': 1, 'completed': 1}), Counter({'statistics': 2, 'RT': 1, '@DataCamp': 1, 'Demystifying': 1, 'crucial': 1, 'in': 1, 'Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'learn': 1, 'about': 1, 'the': 1, 'basic': 1, 'required': 1, 'for': 1, 'Data': 1, 'Science': 1, 'and': 1, 'M': 1}), Counter({'Amen': 1, '@DataCamp': 1, 'is': 1, 'absolutely': 1, 'amazing': 1, 'I': 1, 'm': 1, 'always': 1, 'excited': 1, 'for': 1, 'the': 1, 'next': 1, 'TEMPORARY': 1, 'CHALLENGE': 1, '#codinglife': 1, '#javascript': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Importing': 1, 'Data': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'the': 3, 'RT': 1, '@DataCamp': 1, 'Join': 1, 'us': 1, 'next': 1, 'Thursday': 1, 'for': 1, 'a': 1, 'new': 1, 'live': 1, 'coding': 1, 'event': 1, 'on': 1, 'Facebook': 1, 'Introduction': 1, 'to': 1, 'Tidyverse': 1, 'Survivors': 1, 'of': 1, 'Titanic': 1, 'T': 1}), Counter({'RT': 1, '@HaSN': 1, 'CH': 1, 'DaysOfCode': 1, 'A': 1, '#day': 1, 'well': 1, 'spent': 1, 'on': 1, '@DataCamp': 1, '#DataScience': 1, '#Database': 1, '#sql': 1, '#developers': 1, '#Python': 1}), Counter({'R': 2, '@nskajaa': 1, 'For': 1, 'learning': 1, 'in': 1, 'general': 1, 'I': 1, 'always': 1, 'recommend': 1, '@DataCamp': 1, 'and': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'DaysOfCode': 1, 'A': 1, '#day': 1, 'well': 1, 'spent': 1, 'on': 1, '@DataCamp': 1, '#DataScience': 1, '#Database': 1, '#sql': 1, '#developers': 1, '#Python': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Reporting': 1, 'with': 1, 'R': 1, 'Markdown': 1}), Counter({'RT': 1, '@dataelixir': 1, 'Managing': 1, 'Data': 1, 'Science': 1, 'Teams': 1, 'with': 1, '@AngeBassa': 1, 'via': 1, '@DataCamp': 1}), Counter({'for': 2, '@brandibeals': 1, '@DataCamp': 1, 'Oh': 1, 'well': 1, 'Even': 1, 'though': 1, 'it': 1, 'didn': 1, 't': 1, 'work': 1, 'me': 1, 'thanks': 1, 'posting': 1}), Counter({'about': 2, 'Being': 1, 'a': 1, 'data': 1, 'science': 1, 'manager': 1, 'isn': 1, 't': 1, 'giving': 1, 'your': 1, 'team': 1, 'all': 1, 'the': 1, 'answers': 1, 'it': 1, 's': 1, 'guiding': 1, 'them': 1, 'there': 1, 'instead': 1}), Counter({'RT': 1, '@doodssiton': 1, 'Learned': 1, 'so': 1, 'much': 1, 'sifting': 1, 'through': 1, 'the': 1, 'Visualizing': 1, 'Geospatial': 1, 'Data': 1, 'With': 1, 'Python': 1, 'course': 1, '@DataCamp': 1, 'by': 1, '@marylvv': 1, 'Thank': 1, 'you': 1, 'https': 1}), Counter({'@Gators': 1, '@kearneymw': 1, '@DataCamp': 1, '@dataandme': 1, 'Thank': 1, 'you': 1, 'for': 1, 'the': 1, 'recommendations': 1}), Counter({'RT': 1, '@Mteheran': 1, '@calypso': 1, 'bronte': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'Felicitaciones': 1}), Counter({'@doodssiton': 1, '@DataCamp': 1, 'Glad': 1, 'to': 1, 'hear': 1, 'this': 1}), Counter({'in': 2, 'the': 2, 'RT': 1, '@promptcloud': 1, 'In': 1, 'case': 1, 'you': 1, 'are': 1, 'taken': 1, 'by': 1, '#DataScience': 1, 'buzz': 1, 'take': 1, 'a': 1, 'look': 1, 'at': 1, 'five': 1, 'resources': 1, 'listed': 1, 'this': 1, 'blog': 1}), Counter({'@calypso': 1, 'bronte': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'Felicitaciones': 1}), Counter({'@cringngedup': 1, '@DataCamp': 1, 'Thank': 1, 'you': 1}), Counter({'I': 2, '@iamchantelphd': 1, '@kearneymw': 1, 'would': 1, 'recommend': 1, '@DataCamp': 1, 'really': 1, 'like': 1, 'their': 1, 'teaching': 1, 'method': 1, 'short': 1, 'videos': 1, 'followed': 1, 'b': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Analyzing': 1, 'Election': 1, 'and': 1, 'Polling': 1, 'Data': 1, 'in': 1, 'R': 1}), Counter({'in': 2, 'the': 2, 'In': 1, 'case': 1, 'you': 1, 'are': 1, 'taken': 1, 'by': 1, '#DataScience': 1, 'buzz': 1, 'take': 1, 'a': 1, 'look': 1, 'at': 1, 'five': 1, 'resources': 1, 'listed': 1, 'this': 1, 'blog': 1}), Counter({'@Ugyen': 1, 'Norbu': 1, '@DataCamp': 1, 'Congratulations': 1, 'boss': 1}), Counter({'@DataScienceFEM': 2, 'RT': 1, 'Thank': 1, 'you': 1, '@DataCamp': 1, '#DataScientists': 1, '#DataChallenge': 1, 'Fem': 1, '#DataScience': 1, '#WomenInTech': 1, '#Python': 1, 'htt': 1}), Counter({'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Intermediate': 1, 'Python': 1, 'for': 1, 'Data': 1, 'Science': 1}), Counter({'Learned': 1, 'so': 1, 'much': 1, 'sifting': 1, 'through': 1, 'the': 1, 'Visualizing': 1, 'Geospatial': 1, 'Data': 1, 'With': 1, 'Python': 1, 'course': 1, '@DataCamp': 1, 'by': 1, '@marylvv': 1, 'Thank': 1, 'you': 1}), Counter({'Learning': 1, 'R': 1, 'is': 1, 'fun': 1, 'Thanks': 1, 'for': 1, 'the': 1, 'great': 1, 'app': 1, '@DataCamp': 1}), Counter({'in': 2, 'my': 2, 'RT': 1, '@suryast': 1, '@DataCamp': 1, 'your': 1, 'iOS': 1, 'app': 1, 'has': 1, 'a': 1, 'weird': 1, 'bug': 1, 'case': 1, 'I': 1, 'am': 1, 'registered': 1, 'youe': 1, 'database': 1, 'using': 1, 'LinkedIn': 1, 'credential': 1, 'Your': 1, 'login': 1}), Counter({'in': 2, 'my': 2, '@DataCamp': 1, 'your': 1, 'iOS': 1, 'app': 1, 'has': 1, 'a': 1, 'weird': 1, 'bug': 1, 'case': 1, 'I': 1, 'am': 1, 'registered': 1, 'youe': 1, 'database': 1, 'using': 1, 'LinkedIn': 1, 'credential': 1}), Counter({'Managing': 1, 'Data': 1, 'Science': 1, 'Teams': 1, 'with': 1, '@AngeBassa': 1, 'via': 1, '@DataCamp': 1}), Counter({'Muy': 1, 'orgullosa': 1, 'Thanks': 1, '@DataCamp': 1, 'ahora': 1, 'somos': 1, 'tal': 1, 'vez': 1}), Counter({'Thank': 1, 'you': 1, '@DataCamp': 1, '@DataScienceFEM': 1, '#DataScientists': 1, '#DataChallenge': 1, 'Fem': 1, '#DataScience': 1, '#WomenInTech': 1, '#Python': 1}), Counter({'RT': 1, '@calypso': 1, 'bronte': 1, 'Nuestro': 1, 'grado': 1, 'como': 1, '#DataScientists': 1, 'con': 1, '@DataScienceFEM': 1, '@DataCamp': 1}), Counter({'Great': 1, 'refresher': 1, 'by': 1, '@drob': 1, 's': 1, '@DataCamp': 1, 'course': 1, 'Introduction': 1, 'to': 1, 'the': 1, 'Tidyverse': 1}), Counter({'Nuestro': 1, 'grado': 1, 'como': 1, '#DataScientists': 1, 'con': 1, '@DataScienceFEM': 1, '@DataCamp': 1}), Counter({'of': 3, 'the': 3, 'RT': 1, '@iris': 1, 'Purpose': 1, 'ready': 1, 'I': 1, 'am': 1, 'very': 1, 'happy': 1, 'because': 1, 'effort': 1, 'dedication': 1, 'help': 1, 'my': 1, 'girls': 1, '@DataScienceFEM': 1, 'and': 1, 'to': 1}), Counter({'RT': 1, '@AgroNatureNig': 1}), Counter({'@keatonwilson': 1, '@Chrismartin': 1, '@JCSkewesDK': 1, '@Gairan': 1, 'P': 1, '@DataCamp': 1, 'Theory': 1, 'vs': 1, 'facts': 1, 'Datacamp': 1, 'has': 1, 'a': 1, 'million': 1, 'people': 1, 'taking': 1, 'their': 1, 'courses': 1}), Counter({'RT': 1, '@danielagsrm': 1, 'Can': 1, 't': 1, 'believe': 1, 'we': 1, 'did': 1, 'it': 1, 'Teach': 1, 'a': 1, 'girl': 1, 'to': 1, 'code': 1, 'and': 1, 'she': 1, 'll': 1, 'change': 1, 'the': 1, 'world': 1, '@DataScienceFEM': 1, 'Thank': 1, 'you': 1, '@DataCamp': 1}), Counter({'of': 4, 'RT': 1, '@hugobowne': 1, 'In': 1, 'Ep': 1, '#DataFramed': 1, 'our': 1, 'Season': 1, 'finale': 1, 'the': 1, '@DataCamp': 1, 'pod': 1, 'I': 1, 'speak': 1, 'with': 1, '@mathbabedotorg': 1, 'author': 1, 'Weapons': 1, 'Math': 1}), Counter({'RT': 1, '@danielagsrm': 1, '@iris': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'CONGRAAAAATS': 1}), Counter({'RT': 1, '@GarbaAdams': 1, '@Navas': 1, 'Sofia': 1, '@IamIgoche': 1, '@DataCamp': 1, '@DataScienceFEM': 1, 'Congrats': 1}), Counter({'m': 2, 'RT': 1, '@iris': 1, '@stifflerBassMan': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'Muchas': 1, 'gracias': 1, 'Tal': 1, 'vez': 1, 's': 1, 'adelante': 1, 'pueda': 1, 'aplicar': 1, 'Aun': 1, 'necesito': 1, 'aprender': 1, 'mucho': 1}), Counter({'@iris': 2, 'RT': 1, '@stifflerBassMan': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'por': 1, 'si': 1, 'te': 1, 'interesa': 1}), Counter({'m': 2, 's': 2, '@stifflerBassMan': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'Muchas': 1, 'gracias': 1, 'Tal': 1, 'vez': 1, 'adelante': 1, 'pueda': 1, 'aplicar': 1, 'Aun': 1, 'necesito': 1, 'aprender': 1, 'mucho': 1}), Counter({'Can': 1, 't': 1, 'believe': 1, 'we': 1, 'did': 1, 'it': 1, 'Teach': 1, 'a': 1, 'girl': 1, 'to': 1, 'code': 1, 'and': 1, 'she': 1, 'll': 1, 'change': 1, 'the': 1, 'world': 1, '@DataScienceFEM': 1, 'Thank': 1, 'you': 1}), Counter({'of': 2, 'RT': 1, '@DataScienceFEM': 1, 'Today': 1, 'graduation': 1, 'the': 1, 'first': 1, 'scholarships': 1, 'our': 1, 'fraternity': 1, '@datasciencefem': 1, '#datachallenge': 1, 'fem': 1, 'sponsored': 1, 'by': 1}), Counter({'@iris': 1, '@DataScienceFEM': 1, '@DataCamp': 1, 'CONGRAAAAATS': 1}), Counter({'WE': 1, 'ARE': 1, 'DONE': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Network': 1, 'Analysis': 1, 'in': 1, 'Python': 1, 'Part': 1}), Counter({'@mrnavrc': 1, '@DataCamp': 1, '@Codecademy': 1, '@hackerrank': 1, 'is': 1, 'a': 1, 'good': 1, 'site': 1, 'with': 1, 'small': 1, 'problems': 1, 'that': 1, 'can': 1, 'make': 1, 'you': 1, 'learn': 1, 'by': 1, 'doing': 1, 'Wor': 1}), Counter({'@iris': 2, '@DataScienceFEM': 1, '@DataCamp': 1, 'por': 1, 'si': 1, 'te': 1, 'interesa': 1}), Counter({'I': 3, 'the': 2, 'RT': 1, '@mrnavrc': 1, 'found': 1, 'out': 1, 'that': 1, 'didn': 1, 't': 1, 'like': 1, 'format': 1, 'of': 1, 'Treehouse': 1, 'Python': 1, 'course': 1, 'sorry': 1, 'guys': 1, 'There': 1, 'are': 1, 'too': 1, 'many': 1, 'videos': 1, 'and': 1, 'need': 1, 'a': 1}), Counter({'I': 2, 'the': 2, 'found': 1, 'out': 1, 'that': 1, 'didn': 1, 't': 1, 'like': 1, 'format': 1, 'of': 1, 'Treehouse': 1, 'Python': 1, 'course': 1, 'sorry': 1, 'guys': 1, 'There': 1, 'are': 1, 'too': 1, 'many': 1, 'videos': 1, 'an': 1}), Counter({'Going': 1, 'deeper': 1, 'I': 1, 'just': 1, 'completed': 1, 'the': 1, 'course': 1, 'Deep': 1, 'Learning': 1, 'in': 1, 'Python': 1}), Counter({'Files': 2, 'In': 2, 'to': 2, 'RT': 1, '@DataCamp': 1, 'New': 1, 'Tutorial': 1, 'Working': 1, 'With': 1, 'Zip': 1, 'Python': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'are': 1, 'going': 1, 'learn': 1, 'how': 1, 'work': 1, 'with': 1, '#Zip': 1, 'in': 1, 'Pytho': 1}), Counter({'to': 2, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'Python': 1, 'Metaclasses': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'learn': 1, 'what': 1, '#metaclasses': 1, 'are': 1, 'how': 1, 'implement': 1, 't': 1}), Counter({'@abhijitnsharma': 1, 'Hello': 1, 'our': 1, 'support': 1, 'team': 1, 'has': 1, 'notified': 1, 'us': 1, 'that': 1, 'the': 1, 'issues': 1, 'have': 1, 'been': 1, 'resolved': 1, 'Thank': 1, 'you': 1, 'for': 1, 'your': 1, 'patience': 1}), Counter({'to': 3, 'RT': 1, '@gelliottmorris': 1, 'Want': 1, 'learn': 1, 'how': 1, 'analyze': 1, 'political': 1, 'data': 1, 'Trying': 1, 'figure': 1, 'out': 1, '#rstats': 1, 'and': 1, 'want': 1, 'a': 1, 'familiar': 1, 'dataset': 1, 'I': 1, 've': 1, 'got': 1, 'somethi': 1}), Counter({'Analyzing': 1, 'Police': 1, 'Activity': 1, 'with': 1, 'pandas': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'practice': 1, 'cleaning': 1, 'messy': 1, 'data': 1, 'create': 1, 'visualizations': 1}), Counter({'with': 2, 'to': 2, 'Modeling': 1, 'Data': 1, 'in': 1, 'the': 1, 'Tidyverse': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'will': 1, 'learn': 1, 'model': 1, 'data': 1, 'Models': 1, 'attempt': 1, 'capture': 1, 't': 1}), Counter({'Did': 1, 'you': 1, 'already': 1, 'get': 1, 'your': 1, 'Pandas': 1, 'basics': 1, 'cheat': 1, 'sheet': 1}), Counter({'Pivot': 1, 'Tables': 1, 'with': 1, 'Spreadsheets': 1, 'Learn': 1, 'techniques': 1, 'such': 1, 'as': 1, 'sorting': 1, 'subtotaling': 1, 'filtering': 1, 'your': 1, 'data': 1, 'using': 1, 'real': 1, 'wor': 1}), Counter({'TensorBoard': 2, 'you': 2, 'Could': 1, 'help': 1, 'This': 1, 'tutorial': 1, 'will': 1, 'guide': 1, 'on': 1, 'how': 1, 'to': 1, 'use': 1, 'which': 1, 'is': 1, 'a': 1, 'fantastic': 1, 'utility': 1, 'th': 1}), Counter({'Intermediate': 1, 'Spreadsheets': 1, 'for': 1, 'Data': 1, 'Science': 1, 'This': 1, 'course': 1, 'will': 1, 'expand': 1, 'your': 1, 'Google': 1, 'Sheets': 1, 'vocabulary': 1, 'You': 1, 'll': 1, 'dive': 1, 'deep': 1}), Counter({'xts': 2, 'Are': 1, 'you': 1, 'manipulating': 1, 'time': 1, 'series': 1, 'data': 1, 'in': 1, 'R': 1, 'with': 1, 'Get': 1, 'your': 1, 'copy': 1, 'of': 1, 'DataCamp': 1, 's': 1, 'cheat': 1, 'sheet': 1, 'here': 1}), Counter({'New': 1, 'Tutorial': 1, 'Shareable': 1, 'Data': 1, 'Science': 1, 'with': 1, '@kyso': 1, 'io': 1, 'Learn': 1, 'how': 1, 'to': 1, 'create': 1, 'publishable': 1, 'and': 1, 'reproducible': 1, 'data': 1, 'science': 1, 's': 1}), Counter({'a': 3, 'Watch': 1, 'new': 1, 'webinar': 1, 'by': 1, '@robinson': 1, 'es': 1, 'data': 1, 'scientist': 1, 'at': 1, 'DataCamp': 1, 'who': 1, 'will': 1, 'give': 1, 'brief': 1, 'introduction': 1, 'to': 1, 'the': 1, 'concep': 1}), Counter({'@mbenchi': 1, 'Hello': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1}), Counter({'Working': 1, 'with': 1, 'Dates': 1, 'and': 1, 'Times': 1, 'in': 1, 'R': 1, 'by': 1, '@CVWickham': 1, 'This': 1, 'course': 1, 'teaches': 1, 'you': 1, 'the': 1, 'essentials': 1, 'of': 1, 'parsing': 1, 'manipulating': 1, 'a': 1}), Counter({'@jpls': 1, 'Hi': 1, 'John': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'look': 1, 'into': 1, 'your': 1, 'specific': 1, 'situation': 1}), Counter({'@shankarSRC': 1, 'Hi': 1, 'Shankar': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'look': 1, 'into': 1, 'your': 1, 'specific': 1, 'issue': 1}), Counter({'@ur': 1, 'zee': 1, '@hugobowne': 1, '@mathbabedotorg': 1, 'Hi': 1, 'Zaid': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'look': 1, 'into': 1, 'your': 1, 'specific': 1, 'issue': 1}), Counter({'New': 1, 'Tutorial': 1, 'Naive': 1, 'Bayes': 1, 'Classification': 1, 'using': 1, 'Scikit': 1, 'learn': 1, 'Learn': 1, 'how': 1, 'to': 1, 'build': 1, 'and': 1, 'evaluate': 1, 'a': 1, '#Naive': 1, '#Bayes': 1}), Counter({'This': 1, '#SciPy': 1, 'SciPy': 1, 'cheat': 1, 'sheet': 1, 'covers': 1, 'the': 1, 'basics': 1, 'of': 1, 'linear': 1, 'algebra': 1, 'in': 1, '#Python': 1, 'that': 1, 'you': 1, 'need': 1, 'to': 1, 'get': 1, 'started': 1}), Counter({'Scikit': 1, 'learn': 1, 'cheat': 1, 'sheet': 1, '#machinelearning': 1, 'with': 1, '#Python': 1}), Counter({'Tutorial': 1, 'Bivariate': 1, 'Distribution': 1, 'Heatmaps': 1, 'in': 1, 'R': 1, 'Learn': 1, 'how': 1, 'to': 1, 'visually': 1, 'show': 1, 'the': 1, 'relationship': 1, 'between': 1, 'two': 1, 'features': 1, 'h': 1}), Counter({'statistics': 2, 'Demystifying': 1, 'crucial': 1, 'in': 1, 'Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'learn': 1, 'about': 1, 'the': 1, 'basic': 1, 'required': 1, 'for': 1, 'Data': 1, 'Sci': 1}), Counter({'@aayushraman': 1, 'Hi': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'assist': 1, 'you': 1, 'with': 1, 'this': 1, 'issue': 1}), Counter({'for': 2, 'New': 1, 'Blog': 1, 'Post': 1, 'by': 1, '@venturidb': 1, 'Request': 1, 'Proposal': 1, 'Topical': 1, 'Projects': 1, 'January': 1, 'Learn': 1, 'how': 1, 'to': 1, 'become': 1, 'a': 1, 'DataCam': 1}), Counter({'In': 2, 'to': 2, 'New': 1, 'Tutorial': 1, 'Working': 1, 'With': 1, 'Zip': 1, 'Files': 1, 'Python': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'are': 1, 'going': 1, 'learn': 1, 'how': 1, 'work': 1, 'with': 1, '#Zip': 1, 'File': 1}), Counter({'New': 1, 'Tutorial': 1, 'Regularization': 1, 'Ridge': 1, 'Lasso': 1, 'and': 1, 'Elastic': 1, 'Net': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'will': 1, 'get': 1, 'acquainted': 1, 'with': 1, 'the': 1, 'bias': 1}), Counter({'nighthawk': 1, 'Hi': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1}), Counter({'and': 2, 'RT': 1, '@data': 1, 'jen': 1, 'I': 1, 'm': 1, 'at': 1, '#wintechseries': 1, 'all': 1, 'week': 1, 'representing': 1, '@DataCamp': 1, 'looking': 1, 'for': 1, '#datascience': 1, '#analytics': 1, 'experts': 1, 'We': 1, 're': 1, 'hiring': 1, 'Mes': 1}), Counter({'New': 1, 'Tutorial': 1, 'Automated': 1, 'Machine': 1, 'Learning': 1, 'with': 1, 'Auto': 1, 'Keras': 1, 'Learn': 1, 'about': 1, 'automated': 1, 'machine': 1, 'learning': 1, 'and': 1, 'how': 1, 'it': 1, 'can': 1, 'be': 1}), Counter({'of': 4, 'RT': 1, '@hugobowne': 1, 'In': 1, 'Ep': 1, '#DataFramed': 1, 'our': 1, 'Season': 1, 'finale': 1, 'the': 1, '@DataCamp': 1, 'pod': 1, 'I': 1, 'speak': 1, 'with': 1, '@mathbabedotorg': 1, 'author': 1, 'Weapons': 1, 'Math': 1}), Counter({'@itsmevidhya': 1, 'k': 1, 'Hi': 1, 'Vidhya': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'if': 1, 'the': 1, 'issue': 1, 'still': 1, 'exists': 1}), Counter({'to': 2, 'Machine': 2, 'Learning': 2, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'in': 1, 'Python': 1, 'Get': 1, 'introduced': 1, 'the': 1, 'world': 1, 'of': 1, '#ML': 1, 'wit': 1}), Counter({'@m': 1, 'in': 1, 's': 1, 'Hi': 1, 'Martin': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'help': 1}), Counter({'New': 1, 'Tutorial': 1, 'Comparison': 1, 'of': 1, 'BI': 1, 'and': 1, 'Analytics': 1, 'Platforms': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'will': 1, 'learn': 1, 'about': 1, 'different': 1, 'factors': 1, 'th': 1}), Counter({'of': 2, 'New': 1, '#DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@mathbabedotorg': 1, 'author': 1, 'Weapons': 1, 'Math': 1, 'Destruction': 1, 'about': 1, 'the': 1}), Counter({'@hizoka': 1, 'andou': 1, 'Hi': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1}), Counter({'This': 1, 'handy': 1, 'one': 1, 'page': 1, 'cheat': 1, 'sheet': 1, 'presents': 1, 'the': 1, '#Python': 1, 'basics': 1, 'that': 1, 'you': 1, 'need': 1, 'to': 1, 'perform': 1, 'data': 1, 'analysis': 1}), Counter({'you': 2, 'Discover': 1, 'why': 1, 'should': 1, 'use': 1, 'Amazon': 1, 'Web': 1, 'Services': 1, 'Elastic': 1, 'Compute': 1, 'Cloud': 1, 'EC': 1, 'and': 1, 'how': 1, 'can': 1, 'set': 1, 'up': 1, 'a': 1, 'basic': 1, 'data': 1, 'sci': 1}), Counter({'Monte': 2, 'Carlo': 2, 'the': 2, 'Introduction': 1, 'to': 1, 'Methods': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'reader': 1, 'will': 1, 'learn': 1, 'methodology': 1, 'and': 1, 'its': 1, 'ap': 1}), Counter({'Working': 1, 'with': 1, '#Spark': 1, '#SQL': 1, 'and': 1, 'DataFrames': 1, 'in': 1, '#Python': 1, 'Get': 1, 'your': 1, '#PySpark': 1, 'SQL': 1, 'cheat': 1, 'sheet': 1}), Counter({'of': 2, 'New': 1, 'Tutorial': 1, 'Overview': 1, 'Atom': 1, '#IDE': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'learn': 1, 'the': 1, 'importance': 1, 'IDEs': 1, 'how': 1, 'to': 1, 'set': 1, 'up': 1, '#Atom': 1, 'an': 1}), Counter({'to': 2, 'DataCamp': 2, 'New': 1, 'Project': 1, 'by': 1, '@venturidb': 1, 'Introduction': 1, 'Projects': 1, 'An': 1, 'introduction': 1, 'projects': 1, 'we': 1, 'll': 1, 'walk': 1, 'you': 1}), Counter({'and': 2, 'The': 1, 'issue': 1, 'has': 1, 'been': 1, 'resolved': 1, 'everything': 1, 'is': 1, 'currently': 1, 'back': 1, 'up': 1, 'running': 1, 'Thank': 1, 'you': 1, 'for': 1, 'your': 1, 'patience': 1}), Counter({'We': 3, 'are': 3, 'working': 2, 'aware': 1, 'that': 1, 'our': 1, 'courses': 1, 'currently': 1, 'down': 1, 'hard': 1, 'to': 1, 'get': 1, 'them': 1, 'back': 1, 'will': 1, 'update': 1, 'you': 1}), Counter({'New': 1, 'Project': 1, 'by': 1, '@ErinLaBrecq': 1, 'Where': 1, 'Are': 1, 'the': 1, 'Fishes': 1, 'In': 1, 'this': 1, 'project': 1, 'you': 1, 'will': 1, 'explore': 1, 'two': 1, 'georeferenced': 1, 'data': 1, 'files': 1, 'c': 1}), Counter({'New': 1, 'Course': 1, 'Multivariate': 1, 'Probability': 1, 'Distributions': 1, 'in': 1, 'R': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'learn': 1, 'about': 1, 'common': 1, '#multivariate': 1}), Counter({'of': 3, 'the': 2, 'RT': 1, '@hugobowne': 1, 'In': 1, 'Ep': 1, '#DataFramed': 1, '@DataCamp': 1, 'podcast': 1, 'I': 1, 'speak': 1, 'with': 1, '@wesmckinn': 1, 'Director': 1, 'Ursa': 1, 'Labs': 1, 'and': 1, 'creator': 1, 'pandas': 1, 'pr': 1}), Counter({'the': 2, 'New': 1, 'Tutorial': 1, 'AdaBoost': 1, 'Classifier': 1, 'in': 1, 'Python': 1, 'Understand': 1, 'ensemble': 1, 'approach': 1, 'working': 1, 'of': 1, '#AdaBoost': 1, 'algorithm': 1, 'a': 1}), Counter({'Learning': 2, 'New': 1, 'Tutorial': 1, 'Differences': 1, 'Between': 1, 'Machine': 1, 'Deep': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'get': 1, 'an': 1, 'overview': 1, 'of': 1, 'Art': 1}), Counter({'of': 2, 'New': 1, 'DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@wesmckinn': 1, 'Director': 1, 'Ursa': 1, 'Labs': 1, 'and': 1, 'creator': 1, 'the': 1, '#pandas': 1, 'project': 1}), Counter({'Scalable': 1, 'Data': 1, 'Processing': 1, 'in': 1, 'R': 1, 'In': 1, 'this': 1, 'course': 1, 'learn': 1, 'tools': 1, 'for': 1, 'processing': 1, 'exploring': 1, 'analyzing': 1, 'data': 1, 'directly': 1, 'fro': 1}), Counter({'to': 2, 'your': 2, 'data': 2, 'If': 1, 'you': 1, 'want': 1, 'take': 1, 'a': 1, 'fresh': 1, 'interactive': 1, 'approach': 1, 'telling': 1, 'story': 1, 'let': 1, 'users': 1, 'interact': 1, 'with': 1, 'and': 1}), Counter({'Spark': 2, 'in': 2, 'Python': 2, 's': 2, 'Apache': 1, 'Beginner': 1, 'Guide': 1, 'A': 1, 'beginner': 1, 'tutorial': 1, 'to': 1, 'based': 1, 'on': 1, 'popular': 1, 'questions': 1, 'su': 1}), Counter({'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'get': 1, 'experience': 1, 'developing': 1, 'fun': 1, 'and': 1, 'realistic': 1, 'Shiny': 1, 'apps': 1, 'for': 1, 'different': 1, 'common': 1, 'use': 1, 'cases': 1, 'such': 1}), Counter({'Apache': 2, 'Spark': 2, 'Tutorial': 1, 'ML': 1, 'with': 1, 'PySpark': 1, 'This': 1, 'tutorial': 1, 'introduces': 1, 'you': 1, 'to': 1, 'big': 1, 'data': 1, 'processing': 1, 'analysis': 1}), Counter({'to': 2, 'R': 2, 'Introduction': 1, 'for': 1, 'Finance': 1, 'by': 1, '@LoreDirick': 1, 'In': 1, 'this': 1, 'finance': 1, 'oriented': 1, 'introduction': 1, 'you': 1, 'will': 1, 'learn': 1, 'essential': 1}), Counter({'for': 2, 'RT': 1, '@ACSundermann': 1, '#DataVisualization': 1, 'is': 1, 'key': 1, 'understanding': 1, 'your': 1, 'own': 1, 'data': 1, 'and': 1, 'communicating': 1, 'findings': 1, 'with': 1, 'others': 1, 'So': 1, 'geeked': 1, 'to': 1, 'ta': 1}), Counter({'New': 1, 'Tutorial': 1, 'Simplifying': 1, 'Sentiment': 1, 'Analysis': 1, 'in': 1, 'Python': 1, 'Learn': 1, 'the': 1, 'basics': 1, 'of': 1, '#sentiment': 1, '#analysis': 1, 'and': 1, 'how': 1, 'to': 1, 'build': 1, 'a': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, 'Tamuno': 1, 'Alfred': 1, 'Designing': 1, 'and': 1, 'Analyzing': 1, 'Clinical': 1, 'Trials': 1, 'in': 1, 'R': 1, 'You': 1, 'll': 1, 'gain': 1, 'an': 1, 'overview': 1, 'of': 1, 'the': 1, 'important': 1}), Counter({'for': 2, '@dirtymodelling': 1, '@nj': 1, 'tierney': 1, 'Hi': 1, 'Sarah': 1, 'thank': 1, 'you': 1, 'letting': 1, 'us': 1, 'know': 1, 'We': 1, 'are': 1, 'looking': 1, 'into': 1, 'it': 1, 'now': 1, 'Also': 1, 'future': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@RallidaeRule': 1, 'Foundations': 1, 'of': 1, 'Functional': 1, 'Programming': 1, 'with': 1, '#purrr': 1, 'Learn': 1, 'to': 1, 'easily': 1, 'extract': 1, 'summarize': 1}), Counter({'R': 2, 'New': 1, 'Course': 1, 'by': 1, '@nj': 1, 'tierney': 1, 'Dealing': 1, 'With': 1, 'Missing': 1, 'Data': 1, 'in': 1, 'Learn': 1, 'how': 1, 'to': 1, 'use': 1, '#tidyverse': 1, 'tools': 1, 'and': 1, 'the': 1, '#naniar': 1, 'pack': 1}), Counter({'RT': 1, '@drivendataorg': 1, 'Listen': 1, 'as': 1, 'our': 1, 'own': 1, '@pjbull': 1, 'a': 1, 'data': 1, 'scientist': 1, 'for': 1, 'social': 1, 'good': 1, 'and': 1, 'co': 1, 'founder': 1, 'of': 1, 'Driven': 1, 'Data': 1, 'talks': 1, 'with': 1, '@hugobowne': 1, 'about': 1, 't': 1}), Counter({'RT': 1, '@MaryLvV': 1, 'I': 1, 'll': 1, 'show': 1, 'you': 1, 'how': 1, 'to': 1, 'get': 1, 'insight': 1, 'from': 1, 'your': 1, '#geospatial': 1, '#data': 1, 'in': 1, 'this': 1, 'DataCamp': 1, 'course': 1, 'using': 1, '#Nashville': 1, '#OpenData': 1, 'Check': 1, 'it': 1, 'out': 1}), Counter({'@xZorex': 1, 'Thank': 1, 'you': 1, 'for': 1, 'bringing': 1, 'this': 1, 'to': 1, 'our': 1, 'attention': 1, 'We': 1, 'will': 1, 'look': 1, 'into': 1, 'it': 1}), Counter({'our': 2, '@mmughal': 1, '@maartenlambert': 1, '@BigData': 1, 'LDN': 1, 'All': 1, 'of': 1, 'cheat': 1, 'sheets': 1, 'are': 1, 'located': 1, 'on': 1, 'Community': 1, 'Here': 1, 'is': 1, 'the': 1, 'link': 1}), Counter({'the': 3, '@JonathanEStarr': 1, 'Hi': 1, 'Jonathan': 1, 'on': 1, 'bottom': 1, 'right': 1, 'of': 1, 'course': 1, 'page': 1, 'datasets': 1, 'are': 1, 'available': 1, 'for': 1, 'you': 1, 'to': 1, 'download': 1}), Counter({'a': 2, 'RT': 1, '@hugobowne': 1, 'I': 1, 'am': 1, 'having': 1, 'helluva': 1, 'time': 1, 'editing': 1, 'next': 1, 'week': 1, 's': 1, 'ep': 1, 'of': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'podcast': 1, 'conversation': 1, 'w': 1, '@wesmckinn': 1, 'about': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@MaryLvV': 1, 'Visualizing': 1, 'Geospatial': 1, 'Data': 1, 'in': 1, 'Python': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'learn': 1, 'to': 1, 'make': 1, 'attractive': 1}), Counter({'our': 2, '@EnterEnergy': 1, '@maartenlambert': 1, '@BigData': 1, 'LDN': 1, 'All': 1, 'of': 1, 'cheat': 1, 'sheets': 1, 'are': 1, 'located': 1, 'on': 1, 'Community': 1, 'Here': 1, 'is': 1, 'the': 1, 'link': 1}), Counter({'RT': 1, '@maartenlambert': 1, 'Come': 1, 'and': 1, 'collect': 1, 'your': 1, 'DataCamp': 1, 'swag': 1, 'at': 1, 'our': 1, '@BigData': 1, 'LDN': 1, 'stand': 1, 'today': 1, 'We': 1, 'also': 1, 'handout': 1, 'free': 1, 'trials': 1, 'for': 1, 'everyone': 1, 'passing': 1, 'b': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@emilyriederer': 1, 'Financial': 1, 'Analytics': 1, 'in': 1, 'R': 1, 'This': 1, 'course': 1, 'is': 1, 'an': 1, 'intro': 1, 'to': 1, 'the': 1, 'world': 1, 'of': 1, '#finance': 1, 'where': 1, 'cash': 1}), Counter({'of': 2, 'RT': 1, '@hugobowne': 1, 'In': 1, 'Episode': 1, '#DataFramed': 1, 'a': 1, '@DataCamp': 1, 'pod': 1, 'I': 1, 'speak': 1, 'with': 1, '@AngeBassa': 1, 'Director': 1, 'Data': 1, 'Science': 1, 'at': 1, '@iRobot': 1, 'about': 1, 'managing': 1}), Counter({'to': 2, 'course': 2, 'is': 2, '@ashutoshkaushal': 1, 'Hey': 1, 'the': 1, 'first': 1, 'chapter': 1, 'every': 1, 'free': 1, 'and': 1, 'so': 1, 'our': 1, 'entire': 1, 'Introduction': 1, 'R': 1, 'Here': 1}), Counter({'Cluster': 1, 'analysis': 1, 'is': 1, 'used': 1, 'to': 1, 'find': 1, 'groups': 1, 'of': 1, 'observations': 1, 'that': 1, 'share': 1, 'similar': 1, 'characteristics': 1, 'This': 1, 'course': 1, 'will': 1, 'introd': 1}), Counter({'RT': 1, '@Rbloggers': 1, 'Angela': 1, 'Bassa': 1, 'discusses': 1, 'managing': 1, 'data': 1, 'science': 1, 'teams': 1, 'and': 1, 'much': 1, 'more': 1}), Counter({'New': 1, 'DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@AngeBassa': 1, 'Director': 1, 'of': 1, 'Data': 1, 'Science': 1, 'at': 1, '@iRobot': 1, 'about': 1, 'leading': 1, 'data': 1}), Counter({'Stemming': 2, 'Lemmatization': 2, 'in': 2, 'and': 1, 'Python': 1, 'This': 1, 'tutorial': 1, 'covers': 1, 'the': 1, 'introduction': 1, 'to': 1, 'used': 1, 'Tex': 1}), Counter({'Working': 1, 'with': 1, 'Dates': 1, 'and': 1, 'Times': 1, 'in': 1, 'R': 1, 'by': 1, '@CVWickham': 1, 'This': 1, 'course': 1, 'teaches': 1, 'you': 1, 'the': 1, 'essentials': 1, 'of': 1, 'parsing': 1, 'manipulating': 1, 'a': 1}), Counter({'in': 2, 'Graph': 1, 'Optimization': 1, 'with': 1, 'NetworkX': 1, 'Python': 1, 'This': 1, '#NetworkX': 1, 'tutorial': 1, 'will': 1, 'show': 1, 'you': 1, 'how': 1, 'to': 1, 'do': 1, 'graph': 1, 'optimization': 1}), Counter({'R': 2, 'Shiny': 2, 'Building': 1, 'Web': 1, 'Applications': 1, 'in': 1, 'with': 1, 'by': 1, '@minebocek': 1, 'This': 1, 'course': 1, 'will': 1, 'take': 1, 'you': 1, 'from': 1, 'programmer': 1, 'to': 1, 'devel': 1}), Counter({'Highcharter': 2, 'to': 2, 'a': 2, 'Data': 1, 'Visualization': 1, 'with': 1, 'in': 1, 'R': 1, 'Learn': 1, 'how': 1, 'use': 1, 'create': 1, 'visualization': 1, 'that': 1, 'creates': 1, 'buz': 1}), Counter({'Unsupervised': 1, 'Learning': 1, 'in': 1, 'R': 1, 'by': 1, '@hankroark': 1, 'This': 1, 'course': 1, 'provides': 1, 'a': 1, 'basic': 1, 'introduction': 1, 'to': 1, 'clustering': 1, 'and': 1, 'dimensionalit': 1}), Counter({'Take': 1, 'our': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Finance': 1, 'course': 1, 'taught': 1, 'by': 1, '@teeniedeenie': 1, 'The': 1, 'financial': 1, 'industry': 1, 'is': 1, 'increasingly': 1, 'adoptin': 1}), Counter({'of': 2, 'a': 2, 'RT': 1, '@hugobowne': 1, 'Get': 1, 'ready': 1, 'for': 1, 'next': 1, 'week': 1, 's': 1, 'ep': 1, '#DataFramed': 1, '@DataCamp': 1, 'pod': 1, 'conversation': 1, 'w': 1, '@AngeBassa': 1, 'Director': 1, 'Data': 1, 'Science': 1, '@iRobot': 1}), Counter({'you': 2, '@goonereyang': 1, 'Hi': 1, 'thank': 1, 'for': 1, 'bringing': 1, 'this': 1, 'to': 1, 'our': 1, 'attention': 1, 'could': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'with': 1, 'a': 1}), Counter({'to': 2, 'RT': 1, '@rstatsnyc': 1, 'Emily': 1, 'Robinson': 1, 'from': 1, '@datacamp': 1, 'walks': 1, 'us': 1, 'through': 1, 'how': 1, 'set': 1, 'up': 1, 'A': 1, 'B': 1, 'testing': 1, 'discover': 1, 'meaningful': 1, 'insights': 1, '#rstatsdc': 1, '@robinso': 1}), Counter({'Monte': 2, 'Carlo': 2, 'the': 2, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'to': 1, 'Methods': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'reader': 1, 'will': 1, 'learn': 1, 'methodol': 1}), Counter({'Preprocessing': 1, 'for': 1, 'Machine': 1, 'Learning': 1, 'in': 1, 'Python': 1, 'This': 1, '#Python': 1, 'course': 1, 'by': 1, '@sarah': 1, 'guido': 1, 'covers': 1, 'the': 1, 'basics': 1, 'of': 1, 'how': 1, 'and': 1, 'when': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@HEX': 1, 'x': 1, 'C': 1, 'Network': 1, 'Science': 1, 'in': 1, 'R': 1, 'A': 1, 'Tidy': 1, 'Approach': 1, 'This': 1, 'course': 1, 'will': 1, 'demonstrate': 1, 'network': 1, 'analysis': 1, 'using': 1}), Counter({'RT': 1, '@mona': 1, 'khm': 1, 'How': 1, 'we': 1, 'create': 1, 'simulated': 1, 'data': 1, 'sets': 1, 'here': 1, 'at': 1, '@DataCamp': 1, 'Thanks': 1, 'to': 1, '@HillGreenLerman': 1, 'for': 1, 'coordinating': 1, 'this': 1}), Counter({'RT': 1, '@HillGreenLerman': 1, 'The': 1, 'folks': 1, 'at': 1, '@DataCamp': 1, 'are': 1, 'having': 1, 'fun': 1, 'coming': 1, 'up': 1, 'with': 1, 'Data': 1, 'Science': 1, 'themed': 1, 'TV': 1, 'Shows': 1, '#datascience': 1, '#nerds': 1, '@mona': 1, 'khm': 1, 'https': 1}), Counter({'RT': 1, '@pjbull': 1, 'it': 1, 's': 1, 'always': 1, 'such': 1, 'a': 1, 'delight': 1, 'to': 1, 'talk': 1, 'with': 1, '@hugobowne': 1, 'given': 1, 'his': 1, 'insightful': 1, 'questions': 1, 'and': 1, 'thoughtful': 1, 'engagement': 1, 'Glad': 1, 'one': 1, 'of': 1, 'our': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, 'Frank': 1, 'Sumanski': 1, 'Pivot': 1, 'Tables': 1, 'with': 1, '#Spreadsheets': 1, 'Learn': 1, 'techniques': 1, 'such': 1, 'as': 1, 'sorting': 1, 'subtotaling': 1, 'fil': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@richierocks': 1, 'Intermediate': 1, '#Spreadsheets': 1, 'for': 1, 'Data': 1, 'Science': 1, 'This': 1, 'course': 1, 'will': 1, 'expand': 1, 'your': 1, 'Google': 1, 'Sheets': 1}), Counter({'of': 3, 'RT': 1, '@hugobowne': 1, 'In': 1, 'Episode': 1, '#DataFramed': 1, 'a': 1, '@DataCamp': 1, 'pod': 1, 'I': 1, 'speak': 1, 'with': 1, '@pjbull': 1, '@drivendataorg': 1, 'about': 1, 'the': 1, 'importance': 1, 'human': 1, 'centered': 1}), Counter({'Dask': 2, 'Parallel': 1, 'Computing': 1, 'with': 1, 'This': 1, 'course': 1, 'will': 1, 'introduce': 1, 'you': 1, 'to': 1, 'a': 1, 'flexible': 1, 'parallel': 1, 'computing': 1, 'library': 1, 'for': 1, 'ana': 1}), Counter({'in': 2, 'In': 1, 'honor': 1, 'of': 1, '#ElectionDay': 1, 'the': 1, 'US': 1, 'take': 1, 'our': 1, 'new': 1, 'Analyzing': 1, '#Election': 1, 'and': 1, '#Polling': 1, 'Data': 1, 'R': 1, 'course': 1, 'by': 1}), Counter({'RT': 1, '@drivendataorg': 1}), Counter({'New': 1, '#DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@pjbull': 1, 'a': 1, 'data': 1, 'scientist': 1, 'for': 1, 'social': 1, 'good': 1, 'and': 1, 'co': 1, 'founder': 1, 'of': 1}), Counter({'you': 2, 'course': 2, 'Have': 1, 'taken': 1, 'our': 1, 'new': 1, 'Analyzing': 1, 'Election': 1, 'and': 1, 'Polling': 1, 'Data': 1, 'in': 1, 'R': 1, 'by': 1, '@gelliottmorris': 1, 'In': 1, 'this': 1, 'll': 1, 'a': 1}), Counter({'@tbalci': 1, 'Please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1}), Counter({'Time': 1, 'series': 1, 'are': 1, 'all': 1, 'around': 1, 'us': 1, 'from': 1, 'server': 1, 'logs': 1, 'to': 1, 'high': 1, 'frequency': 1, 'financial': 1, 'data': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'will': 1, 'learn': 1, 'ev': 1}), Counter({'Apache': 2, 'Spark': 2, 'Tutorial': 1, 'ML': 1, 'with': 1, 'PySpark': 1, 'This': 1, 'tutorial': 1, 'introduces': 1, 'you': 1, 'to': 1, 'big': 1, 'data': 1, 'processing': 1, 'analysis': 1}), Counter({'in': 2, 'day': 2, 'Many': 1, 'phenomena': 1, 'our': 1, 'to': 1, 'lives': 1, 'such': 1, 'as': 1, 'the': 1, 'movement': 1, 'of': 1, 'stock': 1, 'prices': 1, 'are': 1, 'measured': 1, 'intervals': 1, 'over': 1, 'a': 1, 'peri': 1}), Counter({'Spark': 2, 'in': 2, 'Python': 2, 's': 2, 'Apache': 1, 'Beginner': 1, 'Guide': 1, 'A': 1, 'beginner': 1, 'tutorial': 1, 'to': 1, 'based': 1, 'on': 1, 'popular': 1, 'questions': 1, 'su': 1}), Counter({'to': 2, 'R': 2, 'Introduction': 1, 'for': 1, 'Finance': 1, 'by': 1, '@LoreDirick': 1, 'In': 1, 'this': 1, 'finance': 1, 'oriented': 1, 'introduction': 1, 'you': 1, 'will': 1, 'learn': 1, 'essential': 1}), Counter({'@masadowski': 1, 'Hi': 1, 'Mark': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'better': 1, 'assist': 1, 'you': 1}), Counter({'in': 2, 'New': 1, 'Tutorial': 1, 'JSON': 1, 'Data': 1, 'Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'learn': 1, 'about': 1, 'different': 1, 'ways': 1, 'to': 1, 'use': 1, '#JSON': 1, '#Python': 1}), Counter({'a': 2, 'New': 1, 'Tutorial': 1, 'Essentials': 1, 'of': 1, 'Linear': 1, 'Regression': 1, 'in': 1, 'Python': 1, 'Learn': 1, 'what': 1, 'formulates': 1, 'regression': 1, 'problem': 1, 'and': 1, 'how': 1}), Counter({'RT': 1, '@gelliottmorris': 1, 'Hello': 1, 'Today': 1, 'is': 1, 'an': 1, 'exciting': 1, 'day': 1, 'for': 1, 'we': 1, 'officially': 1, 'launch': 1, 'my': 1, '#Rstats': 1, 'course': 1, 'teaching': 1, 'data': 1, 'science': 1, 'with': 1, 'analyses': 1, 'of': 1}), Counter({'RT': 1, '@Rbloggers': 1, 'New': 1, 'Course': 1, 'Analyzing': 1, 'Election': 1, 'and': 1, 'Polling': 1, 'Data': 1, 'in': 1, 'R': 1}), Counter({'@gary': 1, 'thomas': 1, '@DannyProl': 1, '@gelliottmorris': 1, 'Analyzing': 1, 'Election': 1, 'and': 1, 'Polling': 1, 'Data': 1, 'in': 1, 'R': 1, 'Here': 1, 'is': 1, 'the': 1, 'link': 1}), Counter({'RT': 1, '@DannyProl': 1, 'Just': 1, 'finished': 1, '@gelliottmorris': 1, 'course': 1, 'on': 1, '@DataCamp': 1, 'He': 1, 'is': 1, 'an': 1, 'amazing': 1, 'professor': 1, 'hope': 1, 'he': 1, 'will': 1, 'do': 1, 'more': 1, 'courses': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@gelliottmorris': 1, 'Analyzing': 1, '#Election': 1, 'and': 1, '#Polling': 1, 'Data': 1, 'In': 1, 'this': 1, 'course': 1, 'learn': 1, 'how': 1, 'to': 1, 'wrangle': 1, 'visualiz': 1}), Counter({'New': 1, 'Project': 1, '#Python': 1, 'by': 1, '@rabaath': 1, 'A': 1, 'Visual': 1, 'History': 1, 'of': 1, 'Nobel': 1, 'Prize': 1, 'Winners': 1, 'In': 1, 'this': 1, 'project': 1, 'you': 1, 'get': 1, 'to': 1, 'explore': 1, 'pat': 1}), Counter({'RT': 1, '@Rbloggers': 1, 'Arnaub': 1, 'Chatterjee': 1, 'discusses': 1, 'artificial': 1, 'intelligence': 1, 'AI': 1, 'and': 1, 'machine': 1, 'learning': 1, 'ML': 1, 'in': 1}), Counter({'with': 2, 'RT': 1, '@ayanalytics': 1, 'Want': 1, 'to': 1, 'learn': 1, 'about': 1, '#healthcare': 1, '#DataAnalytics': 1, 'real': 1, 'data': 1, 'Check': 1, 'out': 1, 'the': 1, 'project': 1, 'I': 1, 'designed': 1, 'for': 1, '@DataCamp': 1, 'step': 1, 'by': 1}), Counter({'of': 2, 'RT': 1, '@hugobowne': 1, 'In': 1, 'Episode': 1, '#DataFramed': 1, 'a': 1, '@DataCamp': 1, 'pod': 1, 'I': 1, 'speaks': 1, 'with': 1, '@AK': 1, 'Chatterjee': 1, '@McKAnalytics': 1, 'as': 1, 'he': 1, 'cuts': 1, 'through': 1, 'the': 1, 'hype': 1, 'abo': 1}), Counter({'New': 1, 'Project': 1, 'by': 1, '@ayanalytics': 1, 'What': 1, 'Your': 1, 'Heart': 1, 'Rate': 1, 'Is': 1, 'Telling': 1, 'You': 1, 'In': 1, 'this': 1, 'R': 1, 'project': 1, 'you': 1, 'will': 1, 'examine': 1, 'the': 1, 'relations': 1}), Counter({'the': 2, 'New': 1, 'Course': 1, 'by': 1, '@CrackedEggman': 1, 'Machine': 1, 'Learning': 1, 'in': 1, 'Tidyverse': 1, 'This': 1, 'course': 1, 'will': 1, 'teach': 1, 'you': 1, 'to': 1, 'leverage': 1, 'tools': 1, 'i': 1}), Counter({'you': 2, 'start': 2, 'With': 1, 'this': 1, 'beginner': 1, 'tutorial': 1, 'll': 1, 'to': 1, 'explore': 1, 'PEP': 1, 'Python': 1, 's': 1, 'style': 1, 'guide': 1, 'so': 1, 'that': 1, 'can': 1, 'formatting': 1}), Counter({'RT': 1, '@AshleyLucchese': 1, 'One': 1, 'of': 1, 'our': 1, '#analytics': 1, 'experts': 1, 'recently': 1, 'spoke': 1, 'with': 1, '@hugobowne': 1, 'for': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'podcast': 1, 'about': 1, 'cutting': 1, 'thro': 1}), Counter({'about': 2, 'RT': 1, '@koehrsen': 1, 'will': 1, 'Thoroughly': 1, 'enjoyed': 1, 'this': 1, 'DataCamp': 1, 'podcast': 1, '@AllenDowney': 1, 'talks': 1, 'how': 1, 'to': 1, 'think': 1, 'and': 1, 'model': 1, 'uncertainty': 1, 'in': 1, 'real': 1, 'worl': 1}), Counter({'RT': 1, '@old': 1, 'man': 1, 'chester': 1, 'Curious': 1, 'about': 1, 'what': 1, 'it': 1, 'takes': 1, 'to': 1, 'build': 1, 'premium': 1, '#rstats': 1, '#python': 1, '#sql': 1, 'or': 1, '#spreadsheets': 1, 'content': 1, 'for': 1, '@DataCamp': 1, 'We': 1, 've': 1, 'rev': 1}), Counter({'to': 2, 'you': 2, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'MongoDB': 1, 'and': 1, 'Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'll': 1, 'learn': 1, 'how': 1, 'integrate': 1, '#MongoDB': 1, 'with': 1}), Counter({'the': 3, 'RT': 1, '@DigitalMcKinsey': 1, 'Check': 1, 'out': 1, 'latest': 1, '#DataFramed': 1, '@DataCamp': 1, 'podcast': 1, 'where': 1, 'we': 1, 'cut': 1, 'through': 1, 'hype': 1, 'on': 1, '#AI': 1, 'and': 1, 'machine': 1, 'learning': 1, 'in': 1}), Counter({'New': 1, 'DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@AK': 1, 'Chatterjee': 1, 'of': 1, '@McKAnalytics': 1, 'to': 1, 'discuss': 1, 'cutting': 1, 'through': 1, 'the': 1, 'hype': 1}), Counter({'in': 2, 'R': 2, 'New': 1, 'Tutorial': 1, 'Merging': 1, 'Datasets': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'learn': 1, 'to': 1, 'join': 1, 'multiple': 1, 'datasets': 1}), Counter({'Highcharter': 2, 'to': 2, 'a': 2, 'Data': 1, 'Visualization': 1, 'with': 1, 'in': 1, 'R': 1, 'Learn': 1, 'how': 1, 'use': 1, 'create': 1, 'visualization': 1, 'that': 1, 'creates': 1, 'buz': 1}), Counter({'Unsupervised': 1, 'Learning': 1, 'in': 1, 'R': 1, 'by': 1, '@hankroark': 1, 'This': 1, 'course': 1, 'provides': 1, 'a': 1, 'basic': 1, 'introduction': 1, 'to': 1, 'clustering': 1, 'and': 1, 'dimensionalit': 1}), Counter({'NetworkX': 2, 'in': 2, 'Graph': 1, 'Optimization': 1, 'with': 1, 'Python': 1, 'This': 1, 'tutorial': 1, 'will': 1, 'show': 1, 'you': 1, 'how': 1, 'to': 1, 'do': 1, 'graph': 1, 'optimization': 1, 'Py': 1}), Counter({'R': 2, 'Shiny': 2, 'Building': 1, 'Web': 1, 'Applications': 1, 'in': 1, 'with': 1, 'by': 1, '@minebocek': 1, 'This': 1, 'course': 1, 'will': 1, 'take': 1, 'you': 1, 'from': 1, 'programmer': 1, 'to': 1, 'devel': 1}), Counter({'RT': 1, '@hugobowne': 1, 'Launching': 1, 'a': 1, 'wonderful': 1, 'conversation': 1, 'w': 1, '@AK': 1, 'Chatterjee': 1, 'of': 1, '@McKAnalytics': 1, 'tomo': 1, 'on': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'podcast': 1, 'an': 1, 'insider': 1}), Counter({'Stemming': 2, 'Lemmatization': 2, 'in': 2, 'and': 1, 'Python': 1, 'This': 1, 'tutorial': 1, 'covers': 1, 'the': 1, 'introduction': 1, 'to': 1, 'used': 1, 'Tex': 1}), Counter({'Working': 1, 'with': 1, 'Dates': 1, 'and': 1, 'Times': 1, 'in': 1, 'R': 1, 'by': 1, '@CVWickham': 1, 'This': 1, 'course': 1, 'teaches': 1, 'you': 1, 'the': 1, 'essentials': 1, 'of': 1, 'parsing': 1, 'manipulating': 1, 'a': 1}), Counter({'at': 2, 'RT': 1, '@kaelen': 1, 'medeiros': 1, 'lol': 1, 'ing': 1, 'in': 1, 'the': 1, 'best': 1, 'way': 1, '@robinson': 1, 'es': 1, 's': 1, 'talk': 1, 'about': 1, 'building': 1, 'out': 1, 'an': 1, 'A': 1, 'B': 1, 'testing': 1, 'system': 1, '@DataCamp': 1, '#noreastr': 1, 'https': 1}), Counter({'a': 2, 'RT': 1, '@robinson': 1, 'es': 1, '@richierocks': 1, 'shows': 1, 'great': 1, 'trick': 1, 'at': 1, '#noreastr': 1, 'if': 1, 'you': 1, 'have': 1, 'list': 1, 'column': 1, 'col': 1, 'and': 1, 'want': 1, 'to': 1, 'filter': 1, 'for': 1, 'ones': 1, 'that': 1, 'contain': 1}), Counter({'Introduction': 1, 'to': 1, 'Machine': 1, 'Learning': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'get': 1, 'a': 1, 'broad': 1, 'overview': 1, 'of': 1, 'the': 1, 'discipline': 1, 's': 1, 'most': 1, 'common': 1, 'techn': 1}), Counter({'@mc': 1, 'alila': 1, 'XP': 1, 'points': 1, 'are': 1, 'a': 1, 'way': 1, 'to': 1, 'track': 1, 'your': 1, 'progress': 1}), Counter({'brohrer': 1, '@tymwol': 1, 'We': 1, 'have': 1, 'updated': 1, 'the': 1, 'source': 1, 'Thank': 1, 'you': 1, 'for': 1, 'pointing': 1, 'that': 1, 'out': 1}), Counter({'you': 2, 'the': 2, '@mc': 1, 'alila': 1, 'Hi': 1, 'can': 1, 'click': 1, 'on': 1, 'hints': 1, 'show': 1, 'answer': 1, 'and': 1, 'then': 1, 'run': 1, 'script': 1, 'It': 1, 'will': 1, 'give': 1, 'credit': 1, 'for': 1, 'complet': 1}), Counter({'@OleksiyAnokhin': 1, 'Thank': 1, 'you': 1, 'for': 1, 'the': 1, 'feedback': 1, 'it': 1, 's': 1, 'a': 1, 'good': 1, 'suggestion': 1, 'We': 1, 'are': 1, 'working': 1, 'on': 1, 'something': 1, 'related': 1, 'to': 1, 'this': 1}), Counter({'Congrats': 1, 'to': 1, '@bigreddot': 1, '@pwang': 1, 'and': 1, 'the': 1, '@anacondainc': 1, 'team': 1, 'for': 1, 'releasing': 1, '@BokehPlots': 1}), Counter({'to': 2, 'RT': 1, '@hugobowne': 1, 'So': 1, 'excited': 1, 'see': 1, '@BokehPlots': 1, 'out': 1, 'there': 1, 'Congrats': 1, '@bigreddot': 1, '@pwang': 1, '@anacondainc': 1, 'the': 1, 'whole': 1, 'team': 1}), Counter({'to': 2, 'a': 2, 'New': 1, 'Tutorial': 1, 'Turning': 1, 'Machine': 1, 'Learning': 1, 'Models': 1, 'into': 1, 'APIs': 1, 'in': 1, 'Python': 1, 'Learn': 1, 'how': 1, 'create': 1, 'simple': 1, '#API': 1, 'from': 1, 'mach': 1}), Counter({'to': 2, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'Geospatial': 1, 'Data': 1, 'in': 1, '#Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'will': 1, 'use': 1, '#geospatial': 1, '#data': 1, '#plot': 1}), Counter({'of': 2, 'RT': 1, '@hugobowne': 1, 'Chatting': 1, 'w': 1, 'Brian': 1, 'is': 1, 'always': 1, 'a': 1, 'lot': 1, 'fun': 1, 'full': 1, 'insight': 1, 'Stoked': 1, 'to': 1, 'have': 1, 'recorded': 1, 'this': 1, 'and': 1, 'put': 1, 'it': 1, 'out': 1, 'there': 1}), Counter({'RT': 1, '@kyle': 1, 'e': 1, 'walker': 1, 'I': 1, 'm': 1, 'excited': 1, 'to': 1, 'share': 1, 'that': 1, 'my': 1, '@DataCamp': 1, 'course': 1, 'on': 1, 'working': 1, 'with': 1, '@uscensusbureau': 1, 'data': 1, 'in': 1, '#rstats': 1, 'has': 1, 'launched': 1, 'Take': 1, 'the': 1, 'co': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@kyle': 1, 'e': 1, 'walker': 1, 'Analyzing': 1, 'US': 1, 'Census': 1, 'Data': 1, 'in': 1, 'R': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'be': 1, 'able': 1, 'to': 1, 'rapidly': 1, 'visualize': 1}), Counter({'RT': 1, '@hugobowne': 1, 'In': 1, 'Ep': 1, 'of': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'pod': 1, 'I': 1, 'speak': 1, 'w': 1, '@quaesita': 1, 'Chief': 1, 'Decision': 1, 'Scientist': 1, '@googlecloud': 1, 'about': 1, 'decision': 1, 'mak': 1}), Counter({'PROS': 2, 'your': 2, 'RT': 1, '@venturidb': 1, 'CONS': 1, 'OF': 1, 'CREATING': 1, 'A': 1, '@DATACAMP': 1, 'PROJECT': 1, 'Impact': 1, 'a': 1, 'global': 1, 'audience': 1, 'build': 1, '#datascience': 1, 'brand': 1, 'supplement': 1, 'in': 1}), Counter({'time': 2, 'at': 2, 'RT': 1, '@PFF': 1, 'Eric': 1, 'This': 1, 'was': 1, 'a': 1, 'cool': 1, 'thing': 1, 'I': 1, 'started': 1, 'between': 1, 'my': 1, 'UWL': 1, 'and': 1, 'starting': 1, 'full': 1, 'PFF': 1, 'If': 1, 'you': 1, 're': 1, 'interested': 1, 'in': 1, 'one': 1, 'of': 1, 'the': 1, 'b': 1}), Counter({'RT': 1, '@ellisonbg': 1, 'I': 1, 'recently': 1, 'spoke': 1, 'with': 1, '@hugobowne': 1, 'for': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'podcast': 1, 'about': 1, '@ProjectJupyter': 1, 'open': 1, 'source': 1, 'software': 1, 'intera': 1}), Counter({'this': 2, 'RT': 1, '@old': 1, 'man': 1, 'chester': 1, 'Love': 1, 'course': 1, 'by': 1, '@PFF': 1, 'Eric': 1, 'What': 1, 'other': 1, 'mathematical': 1, 'topics': 1, 'would': 1, 'you': 1, 'like': 1, 'to': 1, 'see': 1, 'taught': 1, 'in': 1, 'interactive': 1, 'coding': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@PFF': 1, 'Eric': 1, 'Linear': 1, 'Algebra': 1, 'for': 1, 'Data': 1, 'Science': 1, 'in': 1, 'R': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'learn': 1, 'how': 1, 'to': 1, 'work': 1, 'with': 1, 'vector': 1}), Counter({'to': 2, 'RT': 1, '@noamross': 1, 'Jazzed': 1, 'launch': 1, 'my': 1, 'new': 1, 'course': 1, 'on': 1, '@DataCamp': 1, 'Nonlinear': 1, 'Modeling': 1, 'in': 1, '#rstats': 1, 'with': 1, 'GAMs': 1, 'Learn': 1, 'use': 1, 'Generalized': 1, 'Additive': 1, 'Mode': 1}), Counter({'GAMs': 2, 'how': 2, 'New': 1, 'Course': 1, 'by': 1, '@noamross': 1, 'Nonlinear': 1, 'Modeling': 1, 'in': 1, 'R': 1, 'with': 1, 'In': 1, 'this': 1, 'course': 1, 'you': 1, 'll': 1, 'learn': 1, 'work': 1, 'to': 1, 'con': 1}), Counter({'decision': 2, 'RT': 1, '@Rbloggers': 1, 'Cassie': 1, 'Kozyrkov': 1, 'discusses': 1, 'making': 1, 'and': 1, 'intelligence': 1}), Counter({'RT': 1, '@hugobowne': 1, 'I': 1, 've': 1, 'been': 1, 'thinking': 1, 'a': 1, 'lot': 1, 'about': 1, 'what': 1, 'st': 1, 'century': 1, 'data': 1, 'literacy': 1, 'can': 1, 'look': 1, 'like': 1, 'started': 1, 'writing': 1, 'it': 1, 'down': 1, 'for': 1, '@HarvardBiz': 1, 'Watc': 1}), Counter({'Data': 2, 'RT': 1, '@BillBrazell': 1, 'Your': 1, 'Literacy': 1, 'Depends': 1, 'on': 1, 'Understanding': 1, 'the': 1, 'Types': 1, 'of': 1, 'How': 1, 'They': 1, 're': 1, 'Captured': 1, 'says': 1, '@hugobowne': 1}), Counter({'RT': 1, '@Rbloggers': 1, 'New': 1, 'Course': 1, 'Visualization': 1, 'Best': 1, 'Practices': 1, 'in': 1, 'R': 1}), Counter({'RT': 1, '@Rbloggers': 1, 'New': 1, 'Course': 1, 'Interactive': 1, 'Data': 1, 'Visualization': 1, 'with': 1, 'rbokeh': 1}), Counter({'New': 1, 'Tutorial': 1, 'Stemming': 1, 'and': 1, 'Lemmatization': 1, 'in': 1, '#Python': 1, 'This': 1, 'tutorial': 1, 'covers': 1, 'the': 1, 'introduction': 1, 'to': 1, '#Stemming': 1}), Counter({'RT': 1, '@mona': 1, 'khm': 1, 'What': 1, 'do': 1, 'you': 1, 'want': 1, 'to': 1, 'learn': 1, 'next': 1, 'at': 1, '@DataCamp': 1}), Counter({'RT': 1, '@andrea': 1, 'animals': 1, 'I': 1, 'agree': 1, '@DataCamp': 1, 'is': 1, 'amazing': 1}), Counter({'New': 1, '#DataFramed': 1, 'Episode': 1, '@hugobowne': 1, 'speaks': 1, 'with': 1, '@quaesita': 1, 'Chief': 1, 'Decision': 1, 'Scientist': 1, 'at': 1, '@googlecloud': 1, 'about': 1, 'decisio': 1}), Counter({'of': 2, 'the': 2, 'RT': 1, '@hugobowne': 1, 'Ep': 1, '#DataFramed': 1, '@DataCamp': 1, 'podcast': 1, 'w': 1, '@ellisonbg': 1, 'what': 1, 'has': 1, 'contributed': 1, 'to': 1, 'rise': 1, 'interactive': 1, 'computing': 1, '@Pro': 1}), Counter({'In': 1, 'this': 1, 'tutorial': 1, 'data': 1, 'science': 1, 'meets': 1, 'Search': 1, 'Engine': 1, 'Marketing': 1, 'learn': 1, 'to': 1, 'create': 1, 'Google': 1, 'AdWords': 1, 'campaigns': 1, 'by': 1, 'generatin': 1}), Counter({'Building': 1, 'Chatbots': 1, 'in': 1, 'Python': 1, 'Learn': 1, 'how': 1, 'to': 1, 'turn': 1, 'human': 1, 'language': 1, 'into': 1, 'machine': 1, 'instructions': 1, 'with': 1, 'rule': 1, 'based': 1, 'systems': 1, 'm': 1}), Counter({'Dive': 1, 'into': 1, 'the': 1, 'lyrics': 1, 'of': 1, 'Prince': 1, 's': 1, 'music': 1, 'with': 1, 'R': 1, 'use': 1, 'text': 1, 'mining': 1, 'and': 1, 'Exploratory': 1, 'Data': 1, 'Analysis': 1, 'EDA': 1, 'to': 1, 'shed': 1, 'insight': 1}), Counter({'a': 2, 'the': 2, 'They': 1, 'say': 1, 'that': 1, 'picture': 1, 'is': 1, 'worth': 1, 'thousand': 1, 'words': 1, 'This': 1, 'course': 1, 'teaches': 1, 'you': 1, 'how': 1, 'to': 1, 'leverage': 1, 'power': 1, 'of': 1, 'tidyver': 1}), Counter({'on': 2, 'Learn': 1, 'how': 1, 'to': 1, 'apply': 1, 'matrix': 1, 'factorization': 1, 'user': 1, 'clicks': 1, 'hundreds': 1, 'of': 1, 'names': 1, 'in': 1, 'the': 1, 'recommender': 1, 'system': 1}), Counter({'on': 2, 'Google': 2, 'Learn': 1, 'to': 1, 'set': 1, 'up': 1, 'a': 1, 'data': 1, 'science': 1, 'environment': 1, 'Cloud': 1, 'create': 1, 'an': 1, 'instance': 1, 'Compute': 1, 'Engine': 1, 'install': 1, 'An': 1}), Counter({'to': 2, 'the': 2, 'RT': 1, '@OmaymaS': 1, 'And': 1, 'here': 1, 's': 1, 'my': 1, 'course': 1, 'on': 1, '@DataCamp': 1, 'Thanks': 1, 'everyone': 1, 'who': 1, 'worked': 1, 'with': 1, 'me': 1, 'during': 1, 'previous': 1, 'months': 1, 'beta': 1, 'testers': 1, 'w': 1}), Counter({'In': 2, 'to': 2, 'New': 1, 'Tutorial': 1, 'Introduction': 1, 'To': 1, 'GUI': 1, 'With': 1, 'Tkinter': 1, 'Python': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'are': 1, 'going': 1, 'learn': 1, 'how': 1, 'create': 1}), Counter({'New': 1, 'Tutorial': 1, 'Probability': 1, 'Distributions': 1, 'in': 1, '#Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'you': 1, 'll': 1, 'learn': 1, 'about': 1, 'commonly': 1, 'used': 1, '#probability': 1}), Counter({'a': 2, 'RT': 1, '@hugobowne': 1, 'Got': 1, 'back': 1, 'to': 1, 'my': 1, '#python': 1, 'roots': 1, 'this': 1, 'week': 1, 'gave': 1, 'talk': 1, 'at': 1, '#PyDataNYC': 1, 'released': 1, '@DataCamp': 1, 'pod': 1, 'w': 1, '@ellisonbg': 1, 'about': 1, '@ProjectJupy': 1}), Counter({'R': 3, 'Time': 2, 'Series': 2, 'Analysis': 2, 'using': 2, 'with': 2, 'New': 1, 'Tutorial': 1, 'Learn': 1, 'along': 1, 'a': 1, 'package': 1, 'in': 1, 'for': 1, 'f': 1}), Counter({'to': 2, 'RT': 1, '@NicholasStrayer': 1, 'It': 1, 's': 1, 'a': 1, 'pretty': 1, 'giant': 1, 'honor': 1, 'launch': 1, 'my': 1, 'DataCamp': 1, 'course': 1, 'on': 1, '#dataviz': 1, 'Help': 1, 'bring': 1, 'your': 1, '#rstats': 1, 'viz': 1, 'skills': 1, 'the': 1, 'next': 1, 'lev': 1}), Counter({'Check': 1, 'out': 1, 'this': 1, 'new': 1, 'course': 1, 'by': 1, '@NicholasStrayer': 1, 'who': 1, 'currently': 1, 'is': 1, 'a': 1, '#biostatistician': 1, 'data': 1, 'scientist': 1, '@VanderbiltU': 1, 'Hi': 1}), Counter({'by': 2, 'Get': 1, 'in': 1, 'the': 1, 'Halloween': 1, 'spirit': 1, 'taking': 1, 'this': 1, 'New': 1, 'Project': 1, '@NickSolomon': 1, 'Explore': 1, 's': 1, '#Halloween': 1, 'Candy': 1, 'Rankings': 1}), Counter({'RT': 1, '@hugobowne': 1, 'You': 1, 'won': 1, 't': 1, 'want': 1, 'to': 1, 'miss': 1, 'next': 1, 'week': 1, 's': 1, 'ep': 1, 'of': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'podcast': 1, 'a': 1, 'conversation': 1, 'w': 1, '@quaesita': 1, 'Chief': 1, 'Decision': 1, 'Sc': 1}), Counter({'New': 1, 'Project': 1, 'by': 1, '@richierocks': 1, 'Functions': 1, 'for': 1, 'Food': 1, 'Price': 1, 'Forecasts': 1, 'In': 1, 'this': 1, 'project': 1, 'you': 1, 'will': 1, 'practice': 1, 'writing': 1}), Counter({'Take': 1, 'this': 1, 'new': 1, 'Intro': 1, 'to': 1, 'Python': 1, 'for': 1, 'Finance': 1, 'course': 1, 'taught': 1, 'by': 1, '@teeniedeenie': 1, 'Her': 1, 'research': 1, 'at': 1, 'Iowa': 1, 'State': 1, 'University': 1, 'foc': 1}), Counter({'it': 2, '@fjsosah': 1, 'Thank': 1, 'you': 1, 'for': 1, 'bringing': 1, 'to': 1, 'our': 1, 'attention': 1, 'We': 1, 'will': 1, 'look': 1, 'into': 1}), Counter({'I': 2, 'RT': 1, '@hugobowne': 1, 'hey': 1, 'just': 1, 'gave': 1, 'a': 1, 'talk': 1, 'at': 1, '#PyDataNYC': 1, 'on': 1, 'what': 1, 've': 1, 'discovered': 1, 'about': 1, '#datascience': 1, 'while': 1, 'hosting': 1, '#DataFramed': 1, 'the': 1, '@DataCamp': 1, 'po': 1}), Counter({'RT': 1, '@seanmylaw': 1, '@hugobowne': 1, 'from': 1, '@DataCamp': 1, 'helping': 1, 'us': 1, 'figure': 1, 'out': 1, 'what': 1, 'data': 1, 'scientists': 1, 'really': 1, 'do': 1, '#PyDataNYC': 1}), Counter({'Take': 1, 'our': 1, 'new': 1, 'Data': 1, 'Visualization': 1, 'with': 1, '#rbokeh': 1, 'course': 1, 'taught': 1, 'by': 1, 'Omayma': 1, 'Said': 1, 'She': 1, 'has': 1, 'worked': 1, 'on': 1, 'developing': 1, '#algorithms': 1}), Counter({'Python': 2, 'New': 1, 'Course': 1, 'by': 1, '@teeniedeenie': 1, 'Intro': 1, 'to': 1, 'for': 1, 'Finance': 1, 'The': 1, 'financial': 1, 'industry': 1, 'is': 1, 'increasingly': 1, 'adopting': 1, 'fo': 1}), Counter({'RT': 1, '@Leuven': 1, 'MindGate': 1, 'Our': 1, 'speakers': 1, 'are': 1, 'on': 1, 'a': 1, 'roll': 1, 'On': 1, 'stage': 1, 'is': 1, 'ddmkr': 1, 'Dieter': 1, 'De': 1, 'Mesmaeker': 1, 'from': 1, '@DataCamp': 1, 'How': 1, 'can': 1, 'we': 1, 'teach': 1, 'people': 1, 'data': 1, 'sc': 1}), Counter({'of': 2, 'RT': 1, '@ed': 1, 'berry': 1, 'Nice': 1, 'episode': 1, '@DataCamp': 1, 's': 1, 'podcast': 1, 'with': 1, '@drewconway': 1, 'from': 1, 'March': 1, 'They': 1, 'emphasise': 1, 'the': 1, 'famous': 1, 'Venn': 1, 'diagram': 1, 'is': 1, 'Data': 1, 'Science': 1, 'n': 1}), Counter({'New': 1, 'Course': 1, 'by': 1, '@NicholasStrayer': 1, 'Visualization': 1, 'Best': 1, 'Practices': 1, 'in': 1, 'R': 1, 'This': 1, 'course': 1, 'will': 1, 'help': 1, 'you': 1, 'take': 1, 'your': 1, '#data': 1}), Counter({'RT': 1, '@mona': 1, 'khm': 1, 'I': 1, 'wrote': 1, 'a': 1, 'post': 1, 'for': 1, '@DataCamp': 1, 's': 1, 'blog': 1, 'about': 1, 'learning': 1, 'SQL': 1, 'where': 1, 'to': 1, 'start': 1, 'what': 1, 'are': 1, 'the': 1, 'differences': 1, 'and': 1, 'how': 1, 'we': 1, 'can': 1, 'help': 1, 'you': 1, 'on': 1}), Counter({'@dunjanik': 1, 'Hi': 1, 'please': 1, 'contact': 1, 'support': 1, '@datacamp': 1, 'com': 1, 'They': 1, 'will': 1, 'be': 1, 'able': 1, 'to': 1, 'help': 1, 'you': 1, 'with': 1, 'your': 1, 'specific': 1, 'problem': 1}), Counter({'Data': 2, 'New': 1, 'Course': 1, 'by': 1, 'Omayma': 1, 'Said': 1, 'Interactive': 1, 'Visualization': 1, 'with': 1, 'rbokeh': 1, 'visualization': 1, 'is': 1, 'an': 1, 'integral': 1, 'part': 1, 'of': 1, 'th': 1}), Counter({'as': 2, 'RT': 1, '@manideeplanka': 1, '@DataCamp': 1, 'this': 1, 'animation': 1, 'is': 1, 'beautiful': 1, 'and': 1, 'wonderful': 1, 'your': 1, 'courses': 1, 'are': 1}), Counter({'in': 2, 'New': 1, 'Tutorial': 1, 'Decorators': 1, 'Python': 1, 'In': 1, 'this': 1, 'tutorial': 1, 'learn': 1, 'how': 1, 'to': 1, 'implement': 1, '#decorators': 1, '#Python': 1}), Counter({'great': 2, 'RT': 1, '@drob': 1, 'We': 1, 're': 1, 'hiring': 1, 'an': 1, 'Instructor': 1, 'Recruiting': 1, 'Intern': 1, 'at': 1, '@DataCamp': 1, 'for': 1, 'someone': 1, 'enthusiastic': 1, 'about': 1, 'DataCamp': 1, 'who': 1, 'wants': 1, 'to': 1, 'find': 1}), Counter({'Read': 1, 'our': 1, 'new': 1, 'tutorial': 1, 'on': 1, 'Hacking': 1, 'Date': 1, 'Functions': 1, 'in': 1, '#SQLite': 1})]

# %% [markdown]
# Writing requirements.txt
# ========================
#
# We covered how having a `requirements.txt` file can help your package be more portable by allowing your users to easily recreate its intended environment. In this exercise, you will be writing the contents of a requirements file to a python variable.
#
# _Note, in practice, the code you write in this exercise would be written to it's own `txt` file instead of a variable in your python session._
#
# ### Instructions
#
# *   Write the requirement for `matplotlib` with at least version `3.0.0` or above.
# *   Write the requirement for `numpy` version 1.15.4 exactly.
# *   Write the requirement for `pandas` with at most version 0.22.0.
# *   Write a non-version specific requirement for `pycodestyle`

# %%
# Import local package

import text_analyzer

# Sum word_counts using sum_counters from text_analyzer
word_count_totals = text_analyzer.sum_counters(word_counts)
#word_count_totals = sum_counters(word_counts)

# Plot word_count_totals using plot_counter from text_analyzer
text_analyzer.plot_counter(word_count_totals)
#text_analyzer.plot_counter(word_count_totals)

# %% [markdown]
# Writing requirements.txt
# ========================
#
# We covered how having a `requirements.txt` file can help your package be more portable by allowing your users to easily recreate its intended environment. In this exercise, you will be writing the contents of a requirements file to a python variable.
#
# _Note, in practice, the code you write in this exercise would be written to it's own `txt` file instead of a variable in your python session._
#
# ### Instructions
#
# *   Write the requirement for `matplotlib` with at least version `3.0.0` or above.
# *   Write the requirement for `numpy` version 1.15.4 exactly.
# *   Write the requirement for `pandas` with at most version 0.22.0.
# *   Write a non-version specific requirement for `pycodestyle`

# %%
requirements = """
matplotlib>=3.0.0
numpy==1.15.4
pandas<=0.22.0
pycodestyle
"""

# %% [markdown]
# Creating setup.py
# =================
#
# In order to make your package installable by `pip` you need to create a `setup.py` file. In this exercise you will create this file for the `text_analyzer` package you've been building.
#
# ### Instructions
#
# *   `import` the needed function, `setup`, from the `setuptools` package.
# *   Complete the `name` & `packages` arguments; keep in mind your package is located in a directory named `text_analyzer`.
# *   List yourself as the `author`.

# %%
# %%script false # need to be fixed later
#
# # Import needed function from setuptools
# from setuptools import setup
#
# # Create proper setup to be used by pip
# setup(name='text_analyzer',
#       version='0.0.1',
#       description='Perform and visualize a text anaylsis.',
#       author='Hammam',
#       packages=['text_analyzer'])
# Out:
# Couldn't find program: 'false'

# %% [markdown]
# Listing requirements in setup.py
# ================================
#
# We created a setup.py file earlier, but we forgot to list our dependency on `matplotlib` in the `install_requires` argument. In this exercise you will practice listing your version specific dependencies by correcting the `setup.py` you previously wrote for your `text_analyzer` package.
#
# ### Instructions
#
# *   `import` the needed function, `setup`, from the `setuptools` package.
# *   List yourself as the `author`.
# *   Specify your `install_requires` to require `matplotlib` version `3.0.0` or above.

# %%
# %%script false # need to be fixed later
#
# # Import needed function from setuptools
# from setuptools import setup
#
# # Create proper setup to be used by pip
# setup(name='text_analyzer',
#       version='0.0.1',
#       description='Perform and visualize a text anaylsis.',
#       author='Hammam',
#       packages=['text_analyzer'],
#       install_requires=['matplotlib>=3.0.0'])
# Out:
# Couldn't find program: 'false'
